# %%
# Author: Christine Nguyen
import pandas as pd
import numpy as np
import pickle 
import jieba
import jieba.analyse
import re #re stands for regular expression

from nltk.corpus import stopwords

# %%
# pd.set_option('display.max_rows', 500)
# xiahua = pd.read_pickle("xiahua.pickle")

# %% [markdown]
# # Pickle stuff

# %%
#why we pickle stuff?? 
#We do this so that we don't need to constantly read the text file and put the data into the dataframe. 
#This saves us time running that code, and we can pick up where we left off with the dataframe

# %%
#code to read/open up a pickled file

# xiahua = pd.read_pickle("xiahua.pickle")

# %%
#code to write to a file

# xiahua.to_pickle("xiahua.pickle")
# xiahua.tail()

# %% [markdown]
# ## Read in data

# %%
contents = [] #empty python list

# %%
#parse line by line, and strip contents in line 
with open('pre-discussion-4125.txt', encoding='utf8') as f:
    for line in f:
        line = line.strip() #strip line
        stuff = [x.strip() for x in line.split("\t")] #extract contents in line, split by tab
        contents.append(stuff) #insert into comprehensive list
    f.close() #close reading

# %%
contents #shows everything in the contents list
# Out:
# [['项目id', '第几条主评论', '日期', '是否是回复', '评论者id', '评论文本', '众筹前第几天'],
#  ['3510',
#   '152',
#   '2015/5/6',
#   '0',
#   'gaodapk',
#   '一开始我以为是你们帮设计表白图案那，我想买一件那种把自己设计的图案画到衣服上，就是用丙烯画那种。我有自己初步草图不知UI设计师能否帮完善 再画到衣服上哪？',
#   '-1'],
#  ['3510',
#   '154',
#   '2015/5/6',
#   '0',
#   '158O1319OO6',
#   '我感觉就是UI设计师在拼颜值啊~谁看好他就支持他，颜值高支持多，我有点想支持了。。。',
#   '-1'],
#  ['3510', '156', '2015/5/5', '0', '逆战游戏玩家', '什么时候开卖[疑问]', '-2'],
#  ['3722', '106', '2015/4/27', '0', 'jove0916', '几点开始啊', '-1'],
#  ['3722', '108', '2015/4/27', '0', '有Bigger', '具体什么时间开始呢？', '-1'],
#  ['3722', '109', '2015/4/27', '0', 'jove0916', '什么时候开卖', '-1'],
#  ['3722', '110', '2015/4/27', '0', 'jove0916', '想问下是什么材质，PC？', '-1'],
#  ['3722',
#   '111',
#   '2015/4/27',
#   '0',
#   'cnhkygmm',
#   '外出旅游拍照时，站在景点拍摄，如何放支架？似乎这个东东只适用于有平台可以放支架的场合，外出旅游拍全家福还是得用自拍杆。',
#   '-1'],
#  ['3722',
#   '112',
#   '2015/4/27',
#   '0',
#   '大***爰',
#   '想起过年拍全家福用卷纸挡住机身的狼狈，真是很实用的东西，款式看似简单，但直接了当没有多余的设计[真棒]，看电影也能当支撑架，赞',
#   '-1'],
#  ['3722', '113', '2015/4/27', '0', '2***4', '[吻][吻]棒棒的', '-1'],
#  ['3722',
#   '114',
#   '2015/4/23',
#   '0',
#   'i***u',
#   '定位很明确的产品，色彩，想法都很贴切我们年轻人。不错的产品，价格更亲民就好',
#   '-5'],
#  ['3722',
#   '115',
#   '2015/4/23',
#   '0',
#   'z***3',
#   '看起来不错哦！有相机支架的功能外加遥控，解决了自拍的烦恼！挺酷的⋯',
#   '-5'],
#  ['3722', '115', '2015/4/23', '1', 'z***d', '是手机支架吧！', '-5'],
#  ['3722',
#   '116',
#   '2015/4/23',
#   '0',
#   '1***m',
#   '颜色好看，而且可以调角度的这点设计很巧妙，不错！一直想买个自拍器呢，以后自拍就不用那么折腾了[可爱]',
#   '-5'],
#  ['3722', '117', '2015/4/23', '0', 'jd137603pnl', '这设计好骚[太阳]', '-5'],
#  ['3722',
#   '118',
#   '2015/4/23',
#   '0',
#   '黄怡达',
#   '这个很适合饭局多的朋友.再也不用叫靓女服务员了.[真棒]',
#   '-5'],
#  ['3722',
#   '119',
#   '2015/4/23',
#   '0',
#   'huamei1013',
#   '这个自拍神器太帅了，外形，颜色都是我的菜。',
#   '-5'],
#  ['3722',
#   '120',
#   '2015/4/23',
#   '0',
#   '果***p',
#   '一直想买一个自拍器的啦，这个很赞，出游携带方便，推荐哈哈',
#   '-5'],
#  ['3722', '120', '2015/4/23', '1', '果***p', '到手后试试效果再来说性价比吧', '-5'],
#  ['3722',
#   '121',
#   '2015/4/23',
#   '0',
#   'Catpaw1027',
#   '设计感挺强的，手拿也方便，不愧是设计师设计的啊。以后不用拍大脸了啊，好期待！红色特别好看~',
#   '-5'],
#  ['3722',
#   '122',
#   '2015/4/23',
#   '0',
#   '3***m',
#   '有4个颜色，非常漂亮，使用很方便，再也不用愁没人帮忙拍全家福。期待发售！[玫瑰]',
#   '-5'],
#  ['3722',
#   '123',
#   '2015/4/23',
#   '0',
#   's***1',
#   '看上去不错，也比较方便携带，一直想买一款自拍器，但怕手拿着会抖，这个应该不用担心这个问题了，赞',
#   '-5'],
#  ['3722', '124', '2015/4/23', '0', 'h***i', '[太阳][太阳]赞一个！潮爆了', '-5'],
#  ['3722',
#   '125',
#   '2015/4/21',
#   '0',
#   'caraou',
#   '看起来质感不错，颜色很潮T[偷笑]B20块的，估计颜色不忍直视，而且淘B都没有这个款。',
#   '-7'],
#  ['3722', '126', '2015/4/21', '0', 'wuzexiong622', '有兴趣试试实际操作感觉[玫瑰]', '-7'],
#  ['3722', '127', '2015/4/21', '0', 'charrylo', '颜色很好看，看起来很潮，很想看看实物如何！', '-7'],
#  ['3722',
#   '128',
#   '2015/4/23',
#   '0',
#   '楓***公',
#   '这货就一个手机支架+蓝牙遥控器可以卖这价？？X宝上随便买这2样组合起来也就20，请叫我雷锋，不谢！',
#   '-5'],
#  ['3722', '128', '2015/4/23', '1', 'z***d', '如果能便宜些就最好啦[玫瑰]', '-5'],
#  ['3722',
#   '128',
#   '2015/4/23',
#   '1',
#   'z***d',
#   '我觉得一款产品的价值不应该简单地把他拆分后的单价相加，因为设计师将两款产品整合在一起并解决用户的某些问题也应该不是一件简单的事！',
#   '-5'],
#  ['3722', '128', '2015/4/23', '1', 'Catpaw1027', '难道设计师的设计就不值钱？', '-5'],
#  ['3722', '128', '2015/4/21', '1', 'caraou', 't宝的很丑啊', '-7'],
#  ['3722', '128', '2015/4/21', '1', 's***8', '[大哭]', '-7'],
#  ['3722',
#   '129',
#   '2015/4/21',
#   '0',
#   'jd104945cpy',
#   '69的才20位，对你们的吝啬我只能一声叹息！',
#   '-7'],
#  ['3722', '130', '2015/4/21', '0', '快乐随身带', '我只想问，前置摄像头会比后面的摄像头更好？', '-7'],
#  ['3722', '131', '2015/4/21', '0', '亲转账付费', '这东西都能卖69 ~99 ？？？', '-7'],
#  ['3828', '8', '2015/7/18', '0', 'jd_123811798', '明显的奇葩价高不实用', '-2'],
#  ['5030', '43', '2015/6/3', '0', 'a***1', '手动旋转还是电动的呢', '-2'],
#  ['5030', '44', '2015/6/3', '0', 'jd_99991818', '页面的视频画质不怎么样，有原视频下载吗？', '-2'],
#  ['5030', '45', '2015/6/3', '0', 'heesa', '这不跟360出哪个一样么？', '-2'],
#  ['5030', '46', '2015/6/3', '0', 'x***c', '什么时候开始？', '-2'],
#  ['5030', '47', '2015/6/2', '0', '没问题就好', '记录生活的神器，必须买一个！', '-3'],
#  ['5030', '48', '2015/6/2', '0', 'hedyboy', '真贵啊。要是五折我估计还能有市场。', '-3'],
#  ['5030', '49', '2015/6/2', '0', '快乐随身带', '这功能小蚁运动相机都胜任，而且比这个玩法多！', '-3'],
#  ['5339', '93', '2015/4/22', '0', 'l***8', '这和360WiFi U盘版有什么区别？', '-1'],
#  ['5339',
#   '93',
#   '2015/4/22',
#   '1',
#   'shadow_long',
#   '360多了软件加密保护，而且价格更便宜，下单就送货了，这个嘛，自己琢磨',
#   '-1'],
#  ['5339',
#   '94',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '你给他上线提醒，他也未见得会去购买。直接宣布，便于大家做好准备，相比要求加微信来上线提醒的做法，会更受大家的欢迎。京东众筹里面的上线产品，也都是这样操作的，希望你们也按惯例，谢谢。',
#   '-4'],
#  ['5339',
#   '95',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '二是众筹开始的日期和时间，建议在话题讨论区这里公布，我看到有两位朋友询问开始时间，你们都要求加微信，可以上线提醒，有时候难免给人强制广告的嫌疑，建议向其他众筹产品学习，直接在话题区公布，免得大家还要时刻关注上线提醒，耽误时间，想参加众筹的，知道准确时间是肯定要买的，不想参加的，',
#   '-4'],
#  ['5339',
#   '96',
#   '2015/4/20',
#   '0',
#   'cnhkygmm',
#   '另外补充两点个人看法，仅供参考，一是众筹的云盘容量不是很大，看介绍有8G、16G、32G三种规格，拿来众筹的是16G容量的，建议增加32G容量云盘的众筹档位，价格可以适当高于16G容量的，参加众筹的朋友需要32G的，可以直接购买，免得还要买2个16G的，不方便携带价格也不合算。',
#   '-3'],
#  ['5339',
#   '97',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '电脑可以直接访问云盘，无需安装软件，这点很赞，但不清楚是否可以在电脑上操作，将电脑、云盘、手机三者之间的文件（不限格式）相互随意复制粘贴转移？请说明。总体来说，裤带云盘的设计思路和想法具有创新性，解决的是当前智能手机日常使用中的痛点，值得鼓励。',
#   '-4'],
#  ['5339',
#   '98',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '可以相互无线传输文件吗？有无格式限制？比如我们经常遇到的场景，在外游玩，手机拍摄照片和视频，手机存储空间剩余不多的情况下，需要将手机中的图片视频转移到其他存储盘，但由于随身未携带电脑，无法转移，不知云盘可否实现这一功能？若具有这个功能，是开发云盘最有价值的功能。3、连接电脑后，',
#   '-4'],
#  ['5339',
#   '99',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '访问呀？如何来确保个人文件的隐私保护？请详细说明（即便是用APP来读取，其他人也可以通过安装裤带云APP来读取，始终解决不了隐私保护问题）。我的建议是，可以通过专用APP读取，但在读取云盘文件前，设置密码功能，使用人必须输入密码才能访问云盘中的文件。2、当没有电脑时，云盘与手机之',
#   '-4'],
#  ['5339',
#   '100',
#   '2015/4/19',
#   '0',
#   'cnhkygmm',
#   '1、云盘如何保护个人隐私和云盘中文件的安全？看众筹页面介绍，似乎是以供电与否保障安全，当云盘断电时，别人无法看到云盘中的文件，手机中也不保存曾浏览播放过的文件，思路很好，到不知你们考虑过隐私保护没有？若给云盘供电，云盘自带WIFI，手机无线访问云盘中的文件，那其他人的手机也可以',
#   '-4'],
#  ['5339',
#   '101',
#   '2015/4/18',
#   '0',
#   '男人三十多',
#   '互联网时代，啥都带上个&ldquo;云&rdquo;字，我也是醉了，此云非彼云( ⊙ o ⊙ )啊！',
#   '-5'],
#  ['5339', '102', '2015/4/18', '0', 'you钱555任性', '什么时候上线啊？[太阳]', '-5'],
#  ['5339',
#   '104',
#   '2015/4/18',
#   '0',
#   'shadow_long',
#   '不含电池就麻烦了，假如有电脑在的情景，我还需要拿个U盘来让手机读取？！',
#   '-5'],
#  ['5339', '105', '2015/4/17', '0', '可可阿心', '充好电了待机多久？', '-6'],
#  ['5339',
#   '106',
#   '2015/4/17',
#   '0',
#   'z***l',
#   '新东西还是有点搞不明白：要使用这个云盘，必须是有电源点给它供电才能使用？如果不是，无电源的情况下，能实现什么功能？',
#   '-6'],
#  ['5339', '107', '2015/4/17', '0', 'jd_171404762', '提供云服务吗？', '-6'],
#  ['5339',
#   '108',
#   '2015/4/17',
#   '0',
#   'jd吴金nnu',
#   '看描述看晕了，这玩意到底是干嘛的，不就是插在电脑上管理手机文件的u盘吗',
#   '-6'],
#  ['5339',
#   '108',
#   '2015/4/17',
#   '1',
#   'chinasliu',
#   'USB用来充电，也可以传输文件，但它其实是无线传输来共享的。',
#   '-6'],
#  ['5339', '109', '2015/4/16', '0', 'jd139809wxu', '期待开盘中。', '-7'],
#  ['5339', '110', '2015/4/18', '0', '晓***0', '第一名哦，要不要赞助一个，申请下，以祝你们大卖', '-5'],
#  ['5339', '110', '2015/4/18', '1', 'cnhkygmm', '十处打锣十处有这个人。。。', '-5'],
#  ['5339', '110', '2015/4/16', '1', 'l***b', '每个地方都有你。。。', '-7'],
#  ['5565', '31', '2015/4/14', '0', 'jd_134107obe', '购买电子烟需要注意什么？', '-1'],
#  ['5565', '32', '2015/4/14', '0', 'jd_135903yqj', '电子烟适合哪些人群使用？', '-1'],
#  ['5565', '34', '2015/4/14', '0', 'jd_183125zdb', '电子烟电池一次充电后可以使用多长时间？', '-1'],
#  ['5565', '35', '2015/4/14', '0', 'jd_135287zwv', '电子烟指示灯闪烁是什么意思？', '-1'],
#  ['5565',
#   '36',
#   '2015/4/14',
#   '0',
#   'jd_135301ubz',
#   '电子烟释放的烟雾有传统香烟的烟味难闻，会刺激眼睛吗',
#   '-1'],
#  ['5565',
#   '37',
#   '2015/4/14',
#   '0',
#   'jd_135547snu',
#   '听说这种电子烟吐出来的烟雾很大，老人，妇女，儿童吸食后有危险么？',
#   '-1'],
#  ['5565', '37', '2015/4/14', '1', 'jd_135106inm', '怎么控制啊，交一交吧', '-1'],
#  ['5565', '37', '2015/4/14', '1', 'jd_135301ubz', '烟雾可以随心控制的，亲', '-1'],
#  ['5565', '38', '2015/4/14', '0', 'jd_150137eim', '什么情况下需要更换烟弹？', '-1'],
#  ['5565', '39', '2015/4/14', '0', 'jd_137983boo', '电子烟的工作原理是什么？', '-1'],
#  ['5565',
#   '40',
#   '2015/4/14',
#   '0',
#   'jd_135547snu',
#   '最近买了个，用了用，效果还不错。希望能帮我把烟瘾戒掉。',
#   '-1'],
#  ['5565', '41', '2015/4/14', '0', 'jd_183187vkf', '这种电子烟，经常吸的话对皮肤有坏处么？', '-1'],
#  ['5565', '42', '2015/4/14', '0', 'jd_134287bhm', '烟液的浓度高吗，跟烟草味道有区别吗', '-1'],
#  ['5565',
#   '43',
#   '2015/4/14',
#   '0',
#   'jd_135109lah',
#   '吸烟容易戒烟难啊，试试慢慢戒吧。。。。。。。',
#   '-1'],
#  ['5565', '44', '2015/4/14', '0', 'jd_吴俊霞', '易星电子烟，送晚辈适合送什么款的，什么口味的呢', '-1'],
#  ['5565',
#   '45',
#   '2015/4/14',
#   '0',
#   'jd_187180vfz',
#   '蓝牙电子烟，这么稀奇。没听说过。听起来很赞。',
#   '-1'],
#  ['5565',
#   '46',
#   '2015/4/14',
#   '0',
#   'jd_135607kyn',
#   '买了一根，路上出现点问题，不过店家很好，很快就处理好了，客服态度也很好。很赞！',
#   '-1'],
#  ['5565', '47', '2015/4/14', '0', 'jd_134289zfi', '有用过的没有，怎么样！', '-1'],
#  ['5565', '48', '2015/4/14', '0', 'jd_135549lml', '电子烟充电的时候有什么提示吗', '-1'],
#  ['5565', '49', '2015/4/14', '0', 'jd_135904pmj', '易星电子烟，有在超市或者店铺卖的么？', '-1'],
#  ['5565', '50', '2015/4/14', '0', 'jd_135549lml', '电子烟怎样知道电量已经使用不足了呢', '-1'],
#  ['5565',
#   '51',
#   '2015/4/14',
#   '0',
#   'jd_135549lml',
#   '易星电子烟，什么时候做活动啊，有聚划算吗',
#   '-1'],
#  ['5565',
#   '52',
#   '2015/4/14',
#   '0',
#   'jd_135549lml',
#   '易星电子烟那几款好一些 啊给推荐几款好用的吧，准备送人呢',
#   '-1'],
#  ['5565',
#   '53',
#   '2015/4/14',
#   '0',
#   'jd_135549lml',
#   '亲，电子烟就那一个烟嘴，长时间使用会不会有细菌，有没有备用的',
#   '-1'],
#  ['5565',
#   '54',
#   '2015/4/14',
#   '0',
#   'jd_136128wgc',
#   '蓝牙智能电子烟，这么稀奇，还没见过呢。有用过的朋友么？现在科技就是发达。',
#   '-1'],
#  ['5565',
#   '55',
#   '2015/4/14',
#   '0',
#   'jd_135549lml',
#   '超市里卖的一二十块钱的电子烟可以使用吗，有危害吗',
#   '-1'],
#  ['5565', '55', '2015/4/14', '1', '易星-EASING', '请在官方购买~', '-1'],
#  ['5565', '56', '2015/4/14', '0', 'jd_183125ndh', '有用过的朋友么？介绍介绍吧！', '-1'],
#  ['5565',
#   '57',
#   '2015/4/14',
#   '0',
#   'jd_178173yoe',
#   '不管怎么样，老婆少发脾气了。总要比那二手烟好。',
#   '-1'],
#  ['5565',
#   '58',
#   '2015/4/14',
#   '0',
#   'jd_135340dyk',
#   '东西非常好，完美的替代了实体烟，新手建议以水果味的开始，逐步改用香草味其他的。',
#   '-1'],
#  ['5565',
#   '59',
#   '2015/4/14',
#   '0',
#   'jd_159194jin',
#   '烟雾量也很大，就是感觉没劲，可能是因为是低浓度的烟油，下次换个高浓度的试试',
#   '-1'],
#  ['5565',
#   '60',
#   '2015/4/14',
#   '0',
#   'jd_135340hle',
#   '前段时间给老公买了一个，这次帮朋友也带了一个，一如既往的好，质量好，外观漂亮大气，希望老公和朋友都能戒烟成功',
#   '-1'],
#  ['5565',
#   '61',
#   '2015/4/14',
#   '0',
#   'jd_188237sud',
#   '买过了，烟很大 水果味的很好 很喜欢 已经买过两次了 还想买第三根 用起来也很时尚 带盒子十分气派 烟馆做工十分精致 显档次 很好呢！',
#   '-1'],
#  ['5565',
#   '62',
#   '2015/4/14',
#   '0',
#   'jd_137142mkw',
#   '电子烟是安全的么？对人体有什么危害没有啊',
#   '-1'],
#  ['5565',
#   '63',
#   '2015/4/14',
#   '0',
#   'jd151389abp',
#   '以前用过易星的电子烟 感觉非常的好，现在又推出蓝牙功能了，上次掌柜还说要推出什么新款烟油，可以止咳化痰，缓解咽炎的，好像试一下啊....期待....到时候一起入手...',
#   '-1'],
#  ['5565',
#   '64',
#   '2015/4/14',
#   '0',
#   'jd_135549zmc',
#   '买了根电子烟，觉得挺不错的，买过的有木有，设计很好，拿的出手。',
#   '-1'],
#  ['5565',
#   '65',
#   '2015/4/14',
#   '0',
#   'jd_150126dwr',
#   '易星电子烟哪一款性价比比较高，都有哪几种分类啊',
#   '-1'],
#  ['5565',
#   '66',
#   '2015/4/14',
#   '0',
#   'jd_187186uoa',
#   '买过易星电子烟的朋友，可以说一下效果么？',
#   '-1'],
#  ['5565',
#   '67',
#   '2015/4/14',
#   '0',
#   'jd_150138cqx',
#   '电子烟适合女士吗？有没有外形比较好看的！我比较看中这个。',
#   '-1'],
#  ['5565',
#   '68',
#   '2015/4/14',
#   '0',
#   'jd_136864fht',
#   '电子烟和市场上销售的其他品牌电子烟有哪些不同？',
#   '-1'],
#  ['5565',
#   '69',
#   '2015/4/14',
#   '0',
#   'jd_136864mjt',
#   '平常我要是不吸它的时候，放那比较好呢。听说还可以放冰箱里，真的假的？',
#   '-1'],
#  ['5565', '70', '2015/4/14', '0', 'jd_135108njt', '电子烟指示闪烁是什么意思？', '-1'],
#  ['5565', '71', '2015/4/14', '0', 'jd_137288zyx', '电子烟短路了，会爆炸么？', '-1'],
#  ['5565',
#   '72',
#   '2015/4/14',
#   '0',
#   'jd_137136xww',
#   '想尝试的买个电子烟，懂得人推荐推荐吧，应该怎么选，完全白脖一个，万分感谢！',
#   '-1'],
#  ['5565',
#   '73',
#   '2015/4/14',
#   '0',
#   'jd_136129kbw',
#   '电子烟能产生二手烟么，吐出来的烟雾和烟有啥区别。',
#   '-1'],
#  ['5565',
#   '74',
#   '2015/4/14',
#   '0',
#   'jd_137136onh',
#   '电子烟烟弹插进去抽不出烟。是不是烟弹插进去烟液滴进雾化器就可以拔掉扔了？搞不懂怎么玩。来具体点懂得。我感觉出烟小。',
#   '-1'],
#  ['5565', '75', '2015/4/14', '0', 'jd_159194dua', '买电子烟是国产的比较好，还是进口的？', '-1'],
#  ['5565',
#   '76',
#   '2015/4/14',
#   '0',
#   'jd_137142xsd',
#   '我们这个产品的电子烟，里面的一个烟弹能吸多长时间？',
#   '-1'],
#  ['5565', '77', '2015/4/14', '0', 'jd_137983boo', '吸烟会上瘾，吸电子烟会让人上瘾么？', '-1'],
#  ['5565', '78', '2015/4/14', '0', 'jd_135342jej', '吸电子烟会使身上有难闻的气味么？', '-1'],
#  ['5565',
#   '79',
#   '2015/4/14',
#   '0',
#   'jd_159154loh',
#   '吸电子烟和平常吸烟吸法有什么不同么，吸电子烟会不会让牙齿变黄？',
#   '-1'],
#  ['5565',
#   '80',
#   '2015/4/14',
#   '0',
#   'jd_135108nme',
#   '使用的时候一不小心把烟液洒在了电池上应该怎么办，还能用么？',
#   '-1'],
#  ['5565',
#   '81',
#   '2015/4/14',
#   '0',
#   'jd_187184zvo',
#   '这电子烟出行的时候容易携带么？装的时候会不会很不方便啊，它的使用寿命有多长啊，可以保修么？',
#   '-1'],
#  ['5565',
#   '82',
#   '2015/4/14',
#   '0',
#   'jd_137142vjg',
#   '我烟瘾比较大，如果用的话，要多长时间才能把我的烟瘾戒掉，或者减少啊。',
#   '-1'],
#  ['5565',
#   '83',
#   '2015/4/13',
#   '0',
#   'jd159186cvb',
#   '电子烟电池充满电后屏幕仍然显示short的原因是什么？',
#   '-2'],
#  ['5565', '84', '2015/4/14', '0', 'jd158124vge', '烟瘾比较大，用电子烟管戒掉吗', '-1'],
#  ['5565',
#   '84',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '目前已经有很多用户，使用了易星电子烟后，成功戒掉烟瘾咯[可爱]',
#   '-1'],
#  ['5565', '85', '2015/4/14', '0', 'jd151020edd', '蒸汽烟油对人有害么', '-1'],
#  ['5565',
#   '85',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '烟油的核心材料是进口，通过FDA食品安全认证，请放心~',
#   '-1'],
#  ['5565', '86', '2015/4/14', '0', 'jd158124vpv', '戒烟用哪个口味的最好？', '-1'],
#  ['5565', '86', '2015/4/14', '1', '易星-EASING', '要根据个人习惯哦，', '-1'],
#  ['5565', '87', '2015/4/13', '0', 'jd136024lit', '如何分辨电子烟的好坏？', '-2'],
#  ['5565', '88', '2015/4/14', '0', 'jd136024pxe', '送的烟油是多少的，能问多长时间？', '-1'],
#  ['5565',
#   '88',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '每个档位送的烟油瓶数是不同的，每瓶烟油相当于7-10包烟的量',
#   '-1'],
#  ['5565', '89', '2015/4/13', '0', 'jd159184mno', '亲，给推荐几款女士使用的电子烟呗', '-2'],
#  ['5565', '90', '2015/4/14', '0', 'jd150132gos', '电子烟未成年可以用吗', '-1'],
#  ['5565', '90', '2015/4/14', '1', '易星-EASING', '禁止向未成年人出售的哦', '-1'],
#  ['5565', '91', '2015/4/14', '0', 'jd158124gxi', '什么样的口味最受欢迎？？', '-1'],
#  ['5565',
#   '91',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '水蜜桃味道的是目前最受欢迎的，当然这个还有根据个人习惯滴',
#   '-1'],
#  ['5565', '92', '2015/4/14', '0', 'jd136024pxe', '操作简单吗？', '-1'],
#  ['5565', '92', '2015/4/14', '1', '易星-EASING', '简单实用', '-1'],
#  ['5565', '93', '2015/4/14', '0', 'm***a', '蓝牙电子烟怎样使用的？', '-1'],
#  ['5565', '93', '2015/4/14', '1', '易星-EASING', '支持一个档位试试[可爱]', '-1'],
#  ['5565', '94', '2015/4/14', '0', 'jd159186jnu', '使用电子烟多长时间能戒掉烟瘾', '-1'],
#  ['5565',
#   '94',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '按照替烟周期来看，最短有1个月的，最长有一直没戒掉滴[偷笑]',
#   '-1'],
#  ['5565', '95', '2015/4/14', '0', 'jd137108cjw', '烟液有没有保质期？', '-1'],
#  ['5565',
#   '95',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '现在连水都有保质期的，何况烟液呢，建议每次使用多少烟油，添加多少烟油',
#   '-1'],
#  ['5565', '96', '2015/4/14', '0', 'jd137108ocj', '电子烟掉地上了，开不开机了是什么原因？', '-1'],
#  ['5565', '96', '2015/4/14', '1', '易星-EASING', '联系在线客服，说明情况', '-1'],
#  ['5565', '97', '2015/4/14', '0', 'jd136024cxl', '请问烟雾量怎么控制的？', '-1'],
#  ['5565', '97', '2015/4/14', '1', '易星-EASING', '通过手机App 进行控制~', '-1'],
#  ['5565',
#   '98',
#   '2015/4/13',
#   '0',
#   'jd137108nom',
#   '我男朋友也用电子烟，不知道易星电子烟用着怎么样？',
#   '-2'],
#  ['5565', '99', '2015/4/14', '0', 'jd137108vkf', '这个产品都有什么颜色的，有黑色的吗？', '-1'],
#  ['5565', '99', '2015/4/14', '1', '易星-EASING', '有的，现在只有黑色、银色两款哦', '-1'],
#  ['5565', '100', '2015/4/13', '0', 'jd135491jqz', '亲，电子烟有售后服务吗', '-2'],
#  ['5565', '101', '2015/4/13', '0', 'jd152174qvq', '现在哪款用着比较好一点？', '-2'],
#  ['5565', '102', '2015/4/13', '0', 'jd136024chq', '货到付钱可不可以？', '-2'],
#  ['5565', '103', '2015/4/13', '0', 'jd136024hnx', '可以车载进行充电吗？', '-2'],
#  ['5565',
#   '104',
#   '2015/4/14',
#   '0',
#   'jd134164saz',
#   '一个牌子的烟杆和另一个牌子的烟油混搭会出问题不',
#   '-1'],
#  ['5565', '104', '2015/4/14', '1', '易星-EASING', '建议在官方购买[可爱]', '-1'],
#  ['5565',
#   '105',
#   '2015/4/13',
#   '0',
#   'jd136024hnx',
#   '自带的烟油能用多少时间？ 烟油用完了在哪里购买？提供链接',
#   '-2'],
#  ['5565', '105', '2015/4/14', '1', '丸越', '京东有售啊', '-1'],
#  ['5565', '106', '2015/4/13', '0', 'jd136024yok', '一个能用多长时间，有保修的保障吗？', '-2'],
#  ['5565',
#   '107',
#   '2015/4/14',
#   '0',
#   'jd136024edk',
#   '对于第一次用电子烟的，应该注意哪些事项？',
#   '-1'],
#  ['5565',
#   '107',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '注意口味与浓度的选择，第一次使用，不建议购买高浓度的',
#   '-1'],
#  ['5565', '108', '2015/4/13', '0', 'sootao', '易星电子烟在各电商平台，卖的很好哈', '-2'],
#  ['5565', '109', '2015/4/13', '0', 'jd136024lkl', '有没有女士可以用的电子烟？', '-2'],
#  ['5565', '110', '2015/4/13', '0', 'jd136314jzw', '有懂电子烟的朋友么?请推荐烟油.?', '-2'],
#  ['5565',
#   '110',
#   '2015/4/13',
#   '1',
#   'sootao',
#   '欢迎加QQ群 1244****8  众多电子烟爱好者的聚集地哦',
#   '-2'],
#  ['5565', '111', '2015/4/13', '0', 'jd136314jzw', '是否有权利在公共场所吸电子烟？', '-2'],
#  ['5565', '112', '2015/4/13', '0', 'jd136024gwi', '买电子烟送烟液吗？', '-2'],
#  ['5565', '112', '2015/4/13', '1', 'sootao', '每个档位的产品都有送烟油，请仔细看各档位回报', '-2'],
#  ['5565',
#   '113',
#   '2015/4/13',
#   '0',
#   'jd136314jzw',
#   '电子烟的烟雾会触发动车上的烟雾报警器么？',
#   '-2'],
#  ['5565', '114', '2015/4/13', '0', 'jd151020kra', '充电充几个小时？', '-2'],
#  ['5565', '114', '2015/4/13', '1', 'sootao', '充电3个小时左右', '-2'],
#  ['5565', '115', '2015/4/13', '0', 'l***l', '电子烟跟传统香烟比有何不同？吸电子烟更好吗？', '-2'],
#  ['5565', '116', '2015/4/13', '0', 'jd159184mno', '电子烟和烟油能带上飞机或托运吗?', '-2'],
#  ['5565', '116', '2015/4/13', '1', 'sootao', '可以的哦', '-2'],
#  ['5565',
#   '117',
#   '2015/4/13',
#   '0',
#   'jd134343mtb',
#   '你好，你们家的戒烟器里面的戒烟液一瓶可以用多久',
#   '-2'],
#  ['5565', '118', '2015/4/13', '0', 'jd136314jzw', '如何鉴别电子烟油的好坏', '-2'],
#  ['5565', '119', '2015/4/13', '0', 'jd152174lso', '电子烟烟油里边是否有甲醛？', '-2'],
#  ['5565', '120', '2015/4/13', '0', 'jd159174xzi', '该产品在男士备孕期间是否能够使用？', '-2'],
#  ['5565', '121', '2015/4/13', '0', 't***2', '电子烟里面含尼古丁吗？', '-2'],
#  ['5565',
#   '121',
#   '2015/4/14',
#   '1',
#   'sootao',
#   '电子烟是不含尼古丁的，烟油分有浓度的无浓度的两种，建议购买无浓度的',
#   '-1'],
#  ['5565', '122', '2015/4/14', '0', 'jd134802jvv', '烟液都有些什么味道的啊？', '-1'],
#  ['5565',
#   '122',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '烟液口味有很多种类，有烟草系，水果系，花草系，酒水系、薄荷王等等',
#   '-1'],
#  ['5565', '123', '2015/4/14', '0', 'jd134342cjd', '请问烟液的成分是什么', '-1'],
#  ['5565',
#   '123',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '烟液的主要成份是丙二醇、丙三醇、食用香精、尼古丁等成分，易星烟油是经美国FDA认证食用材料生产。烟液中含有尼古丁替代品，但是不含对人体有毒的像真烟焦油中的一氧化碳，二氧化氮，氢氰酸，丙烯醛，砷，铅，汞等有害物质。',
#   '-1'],
#  ['5565', '124', '2015/4/13', '0', 'jd151020edd', '怎么区分电子烟油的质量高低？', '-2'],
#  ['5565',
#   '125',
#   '2015/4/13',
#   '0',
#   'jd134221xjb',
#   '听朋友介绍，易星电子烟很不错，也想了解一下',
#   '-2'],
#  ['5565', '125', '2015/4/13', '1', 'sootao', '谢谢支持[真棒]', '-2'],
#  ['5565', '126', '2015/4/13', '0', 'jd136024lit', '跟真实的烟草味道一样吗', '-2'],
#  ['5565',
#   '126',
#   '2015/4/13',
#   '1',
#   'sootao',
#   '烟油都是仿烟草口味的，在味道上是接近，在未来也会是越来越接近，因为成分是不一样的，烟油是健康的，不含烟草中的有害物质哦[太阳]',
#   '-2'],
#  ['5565', '127', '2015/4/13', '0', 'jd_雪山飞燕の牛奶', '期待中，希望能帮我戒烟', '-2'],
#  ['5565', '127', '2015/4/13', '1', 'sootao', '[真棒]', '-2'],
#  ['5565', '128', '2015/4/13', '0', '丸越', '每天一包烟，选哪个浓度的？', '-2'],
#  ['5565',
#   '128',
#   '2015/4/14',
#   '1',
#   '易星-EASING',
#   '中浓度或者低浓度都可以的哦，不过建议 选择低浓度的~',
#   '-1'],
#  ['5565', '129', '2015/4/13', '0', 'y***e', '这个东西味道如何?送给长辈的话,应该还行.呵呵', '-2'],
#  ['5565',
#   '129',
#   '2015/4/13',
#   '1',
#   '易星-EASING',
#   '烟油口味若是要接近香烟味道的话，可以选择烟草味道的，送长辈是杠杠的~',
#   '-2'],
#  ['5565', '130', '2015/4/13', '0', 'p***b', '送男朋友应该很不错吧', '-2'],
#  ['5565', '130', '2015/4/13', '1', '易星-EASING', '很不错的，送我吧', '-2'],
#  ['5565', '131', '2015/4/13', '0', 'jd136024sbn', '电子烟好用吗，对身体 有危害吗?', '-2'],
#  ['5565', '131', '2015/4/13', '1', 'jd157672rtn', '味道跟真烟有一点区别，没有危害的', '-2'],
#  ['5565', '132', '2015/4/13', '0', 'jd134161bfb', '电子烟真的能戒烟吗？', '-2'],
#  ['5565',
#   '132',
#   '2015/4/13',
#   '1',
#   '清风笑2013',
#   '我是用来替烟，口感不错，对身体无害，不用苦逼着戒烟了[太阳]',
#   '-2'],
#  ['5705', '224', '2015/4/15', '0', '琴妹发', '关注中，支持一下，这个可以有', '-1'],
#  ['5705', '225', '2015/4/15', '0', '爱伊好', '期待 速度开始吧', '-1'],
#  ['5705', '226', '2015/4/15', '0', '元宝大了', '价格很给力啊', '-1'],
#  ['5705', '227', '2015/4/15', '0', '起维星星', '很好 准备支持一下', '-1'],
#  ['5705', '228', '2015/4/15', '0', 'Q***2', '这个能连接小米电视吗', '-1'],
#  ['5705', '230', '2015/4/15', '0', '起维星星', '老公过生日 我准备送这个了', '-1'],
#  ['5705', '231', '2015/4/15', '0', '秉泽爱你', '看这个价格很是合理  商家你再亏本做啊', '-1'],
#  ['5705', '232', '2015/4/15', '0', '董陈磊', '看起来不错噢，希望能抢个超值的。', '-1'],
#  ['5705', '233', '2015/4/15', '0', '雨箐56', '手机有蓝牙功能就行是吗', '-1'],
#  ['5705', '234', '2015/4/15', '0', '乐轩来了', '看着好好，好像要啊', '-1'],
#  ['5705', '235', '2015/4/15', '0', '佳宸85641', '看着很不错，值得拥有', '-1'],
#  ['5705', '236', '2015/4/15', '0', '流星在线abc', '蓝牙版本多少的？待机时间多长啊？', '-1'],
#  ['5705',
#   '237',
#   '2015/4/15',
#   '0',
#   '轴***宅',
#   '没有219那个档的蓝牙配置器就不能再台式电脑上用吗？',
#   '-1'],
#  ['5705', '237', '2015/4/15', '1', '轴***宅', '所以说 没有那东西 台式电脑就不能用呗', '-1'],
#  ['5705', '238', '2015/4/15', '0', '1-明子-1', '有哪些颜色', '-1'],
#  ['5705', '239', '2015/4/14', '0', '1-明子-1', '期待', '-2'],
#  ['5705', '240', '2015/4/15', '0', 'w***2', '没有看懂如何使用鼠标', '-1'],
#  ['5705', '241', '2015/4/15', '0', '烟***0', '送你们几个字，支持你们，价格合理，众筹成功', '-1'],
#  ['5705', '242', '2015/4/14', '0', '未来的我在哪', '三星note3.可以用吗', '-2'],
#  ['5705', '243', '2015/4/14', '0', '未来的我在哪', '哪天开始 期待！！', '-2'],
#  ['5705', '244', '2015/4/14', '0', '未来的我在哪', '看样不错啊，真的可以实现虚拟按键吗', '-2'],
#  ['5705', '245', '2015/4/14', '0', '顺水--顺风', '1元抽奖后，怎么才能知道自己是否中奖呢', '-2'],
#  ['5705', '245', '2015/4/14', '1', 'l***b', '这么便宜你也抽奖。。。', '-2'],
#  ['5705', '246', '2015/4/14', '0', 'smaas', '这款投影键盘支持苹果系统吗', '-2'],
#  ['5705',
#   '247',
#   '2015/4/14',
#   '0',
#   'y***e',
#   '价格好便宜,之前类似的都300多,这次买个玩玩咯.对了,啥时候开售?',
#   '-2'],
#  ['5930', '341', '2015/4/12', '0', 'jd无事挂心', '期待啥时候开始啊！', '-1'],
#  ['5930', '342', '2015/4/12', '0', '花***1', '[太阳]', '-1'],
#  ['5930', '343', '2015/4/11', '0', 'j***美', '外面很少看到,看到的都不适合,这个样式和我喜欢.', '-2'],
#  ['5930',
#   '344',
#   '2015/4/10',
#   '0',
#   '陈小小小小小小小小贱',
#   '时尚个性,我4个颜色都要,好配衣服啊,哈哈',
#   '-3'],
#  ['5930', '345', '2015/4/10', '0', '魅力廉城', '好想吐槽一下[大哭]', '-3'],
#  ['5930',
#   '346',
#   '2015/4/10',
#   '0',
#   '3***9',
#   '建议你们赶紧重新设计，这款产品太局限女士，男的佩戴好像不好看，应该设计一款男女都使用的',
#   '-3'],
#  ['5930', '347', '2015/4/10', '0', 'jd_170281508', '防不防水？有没有售后保障呢', '-3'],
#  ['5930', '348', '2015/4/10', '0', '3***9', '待机能用多长时间？', '-3'],
#  ['5930',
#   '349',
#   '2015/4/10',
#   '0',
#   'm***n',
#   '屏幕太小，价格太贵。我还以为是翡翠材质的呢。手镯总要选好材质吧',
#   '-3'],
#  ['5930', '350', '2015/4/9', '0', 'jd_KITTYo', '有个缺陷，没有防水功能，试用有局限性', '-4'],
#  ['5930',
#   '351',
#   '2015/4/9',
#   '0',
#   'jd_北极龙',
#   '好期待哦,这个产品款式和功能我喜欢,开车打电话不扣分.赞一个',
#   '-4'],
#  ['5930', '352', '2015/4/9', '0', '187*****458_p', '好丑', '-4'],
#  ['5930',
#   '353',
#   '2015/4/9',
#   '0',
#   'z***l',
#   '一会儿LCD，一会儿LED，文案负点责好么......',
#   '-4'],
#  ['5930',
#   '354',
#   '2015/4/9',
#   '0',
#   '晓***0',
#   '什么时间开始众筹？ps.第一个支持你们的要不要给个惊喜之类的[真棒]',
#   '-4'],
#  ['5954',
#   '224',
#   '2015/4/12',
#   '0',
#   '奇得龍冬强',
#   '非触屏，全按键操作，确实更省电，流畅性应该也能保证，关注一下',
#   '-1'],
#  ['5954', '227', '2015/4/11', '0', 'Nero乐天', '假如充电的坏了，怎么办？有通用的充电口吗？', '-2'],
#  ['5954', '230', '2015/4/11', '0', 'jd139633qtq', '支持语音通话吗', '-2'],
#  ['5954', '231', '2015/4/11', '0', '风声雨声跳票声', '4月13日十点开始吗', '-2'],
#  ['5954', '232', '2015/4/11', '0', '小艳1966', '4月6号就开始等，太到，真墨迹', '-2'],
#  ['5954', '233', '2015/4/11', '0', '陈***0', '支持，大腕!', '-2'],
#  ['5954',
#   '234',
#   '2015/4/11',
#   '0',
#   '凤歌楚狂',
#   '问个问题，GPS是内建在表内吗？表支持wifi么？有没有其他传感器？',
#   '-2'],
#  ['5954', '235', '2015/4/11', '0', 'jd_132623fpv', '好期待', '-2'],
#  ['5954',
#   '236',
#   '2015/4/11',
#   '0',
#   '倾听风铃',
#   '①：如果电池坏了，怎么更换？一般的手机店啥的能更换吗？②：音乐播放、接听电话怎么实现？还是只有单纯的换曲啥的简单控制操作，貌似手机没有音频输出什么的吧？③：充电底座内置多少ma容量，为何说不单是充电底座，更是充电宝？',
#   '-2'],
#  ['5954', '237', '2015/4/10', '0', '承欢99', '支持支持[吻]', '-3'],
#  ['5954', '238', '2015/4/10', '0', 'Stonex', '样子喜欢，上架参与：）', '-3'],
#  ['5954', '239', '2015/4/11', '0', 'c***6', '什么时候开始啊 必须支持一下', '-2'],
#  ['5954', '240', '2015/4/10', '0', 'jd_186820rah', '好东西', '-3'],
#  ['5954', '241', '2015/4/10', '0', 'l***t', '299,不会吧，割血卖肉啊？', '-3'],
#  ['5954', '242', '2015/4/10', '0', '万***v', '支持！顶起来~', '-3'],
#  ['5954', '243', '2015/4/11', '0', '绝***才', '之前在社区见过你，众筹开始就来支持下', '-2'],
#  ['5954', '243', '2015/4/10', '1', '风声雨声跳票声', '哪个社区，我也进去看看啊', '-3'],
#  ['5954', '245', '2015/4/11', '0', '跟我没有关系', '同问，何时开始', '-2'],
#  ['5954',
#   '246',
#   '2015/4/11',
#   '0',
#   '风声雨声跳票声',
#   '几日几时开始众筹，299的名额比499还多，正常使用能几天？',
#   '-2'],
#  ['6175',
#   '107',
#   '2015/4/23',
#   '0',
#   'r***7',
#   '请问&ldquo;4大人群必备之（3贴心主管必备神器。手机云端开关公司房门，远程为同事开门）。该神器真的能开门？',
#   '-1'],
#  ['6175', '109', '2015/4/23', '0', '哲***蓝', '带网关的套餐小贵。。。-_-!', '-1'],
#  ['6175',
#   '110',
#   '2015/4/23',
#   '0',
#   '_金_格_',
#   '套在外面用的 两个 三个开关的装不了吧 现在家里装这样单个开关的找不到了  不实用',
#   '-1'],
#  ['6175',
#   '111',
#   '2015/4/23',
#   '0',
#   '叶枫sp',
#   '要是把技术用在门锁、开窗器、晾衣架、浇花灌溉、喂食器或者投料机上会更有市场',
#   '-1'],
#  ['6175', '112', '2015/4/23', '0', '叶枫sp', '请问舵机是两个吗', '-1'],
#  ['6175', '113', '2015/4/23', '0', 'c***r', '哪天开始？', '-1'],
#  ['6175',
#   '114',
#   '2015/4/22',
#   '0',
#   '蓝色de羽翼',
#   '要网关才能联网开关吗，网关和啪嗒智能开关链接距离多少',
#   '-2'],
#  ['6175',
#   '115',
#   '2015/4/22',
#   '0',
#   'y***0',
#   '我房间是两个86型两键开关并在一齐的，估计套不进去吧，只适用单个86开关?',
#   '-2'],
#  ['6175',
#   '116',
#   '2015/4/22',
#   '1',
#   'z***l',
#   '和这个类似 http://item.jd.com/10212****1.html',
#   '-2'],
#  ['6175',
#   '117',
#   '2015/4/22',
#   '0',
#   'jd139218qcx',
#   '是不是不需要改任何线路，要专业人员安装吗？？？？',
#   '-2'],
#  ['6175', '118', '2015/4/22', '0', 'd***7', '1个红外遥控，能控制2个以上的主机吗？', '-2'],
#  ['6730', '688', '2015/5/5', '0', '翱翔的鹿', '小内衣是什么材质的，可以选不一样大的吧', '-1'],
#  ['6730', '688', '2015/5/5', '1', '翱翔的鹿', '是纯棉的吗？', '-1'],
#  ['6730',
#   '689',
#   '2015/5/5',
#   '0',
#   '淘淘88宝宝',
#   '大家的问题都没有人回复，不知道团队们是在忙什么呢？几个问题希望能够给解答一些1、是否会有辐射，一般电子产品孕妇都是很慎重使用的2、用久了会不会发烫？3、和其他同类产品，有什么优势？先问这些吧，希望能够好用。[憨笑]',
#   '-1'],
#  ['6730', '690', '2015/5/5', '0', '宝宝-华', '什么时候上线，对妇疾是有监测功能提醒常规提醒？', '-1'],
#  ['6730',
#   '691',
#   '2015/5/5',
#   '0',
#   '隐-形-侠',
#   '等不到7月3日以后啊么，能用哪种方法付款最快速拿到东西呢？怀孕都是着急的事啊！',
#   '-1'],
#  ['6730', '692', '2015/5/4', '0', 'jdwisesa', '这个是什么原理，只是根据体温？', '-2'],
#  ['6730', '693', '2015/5/4', '0', '久***9', '温度监测多久记录一次？', '-2'],
#  ['6730', '694', '2015/5/4', '0', '面朝大海Zero', '除了京东，哪还有售卖的呢？', '-2'],
#  ['6730',
#   '695',
#   '2015/5/4',
#   '0',
#   '面朝大海Zero',
#   '一个月没事瞎忙活，累得要死，他可以让我定点交公粮吗？',
#   '-2'],
#  ['6730', '695', '2015/5/4', '1', 'y***0', '估计还可以提示什么时候可以交私粮，哈哈', '-2'],
#  ['6730',
#   '696',
#   '2015/5/4',
#   '0',
#   's***r',
#   '马上搞一个，老婆让天天&ldquo;干活&rdquo;，累死了！',
#   '-2'],
#  ['6730',
#   '697',
#   '2015/5/4',
#   '0',
#   'v***v',
#   '避孕神器vs怀孕神器。看你怎么用了，[奸笑]  ，手动斜眼',
#   '-2'],
#  ['6730', '698', '2015/5/4', '0', 'l***b', '没看懂。。。月经不调的 能监控吗？', '-2'],
#  ['6730', '698', '2015/5/5', '1', 'chouchou0912', '听过可以的呢~我也想试试呢~', '-1'],
#  ['6981', '169', '2015/5/11', '0', 'jd_小z10', '我准备订2个，也能多送枕套吗？', '-1'],
#  ['6981', '169', '2015/5/11', '1', '粤S8021', '是每个项目的前30名吗？', '-1'],
#  ['6981',
#   '170',
#   '2015/5/11',
#   '0',
#   'xwh2056',
#   '&ldquo;您将可以终身免费获得春棉公司推出的每一代新款记忆枕&rdquo;可以理解为：每出一款新产品都会免费给发一个吗？',
#   '-1'],
#  ['6981',
#   '171',
#   '2015/5/11',
#   '0',
#   'xwh2056',
#   '我曾经买过一个记忆枕，一晚上没用完就决定退货了，因为有股很难闻的味道。不知春棉会有味道吗？',
#   '-1'],
#  ['6981',
#   '172',
#   '2015/5/11',
#   '0',
#   'j***8',
#   '这个产品支持7天无条件退货吗。因为如果实际使用不舒服我想退货，需要支持无理由退货我才买。',
#   '-1'],
#  ['6981', '174', '2015/5/11', '0', 'jd_prcgol', '还不上架？？', '-1'],
#  ['6981',
#   '175',
#   '2015/5/11',
#   '0',
#   '粤S8021',
#   '&quot;如果是小孩子不建议用&quot;   12岁以上行吗？',
#   '-1'],
#  ['6981', '176', '2015/5/11', '0', 'a***3', '夏天了，配个凉爽的枕套啊', '-1'],
#  ['6981', '177', '2015/5/11', '0', 't***0', '你们的QQ群，加了都没通过的！这样服务不行的！', '-1'],
#  ['6981', '178', '2015/5/11', '0', '粤S8021', '你好，一家3口那款 规格 是一样的吗？', '-1'],
#  ['6981', '180', '2015/5/8', '0', 'l***b', '有没有QQ群', '-4'],
#  ['6981',
#   '181',
#   '2015/5/8',
#   '0',
#   'Archer宁',
#   '&quot;更换时间会根据这次众筹用户的意见反馈进行升级与开发，正常2年内出新&quot;也就是199元档不支持免费升级，我们自行多花了一笔钱购买了免费升级的权益，同时承担了风险，你们是否升级与开发毕竟是未知数，一旦此次产品的反馈不好，你们是否会继续研究升级，还是改行创其他的业，那就不得而知了',
#   '-4'],
#  ['6981',
#   '182',
#   '2015/5/8',
#   '0',
#   '艾若',
#   '一直不明白，难道所有人都是仰卧这种睡姿吗？侧卧就不需要考虑的，现在的这些记忆枕都是针对仰卧的，示意图也是仰卧的，侧卧就没有所说的效果了？补充一下，如果你们要做侧卧版的，必须【给枕头中间挖个鹅蛋型的洞】，方便耳朵不受挤压！',
#   '-4'],
#  ['6981',
#   '183',
#   '2015/5/8',
#   '0',
#   '问_路',
#   '一直不明白，难道所有人都是仰卧这种睡姿吗？侧卧就不需要考虑的，现在的这些记忆枕都是针对仰卧的，示意图也是仰卧的，侧卧就没有所说的效果了',
#   '-4'],
#  ['6981', '184', '2015/5/8', '0', 'y***8', '是不是每次推出新品都免费升级？', '-4'],
#  ['6981',
#   '185',
#   '2015/5/8',
#   '0',
#   'L丶白',
#   '免费升级你说的选出符合的客服，这个怎么说。我买288档的就一定是会免费升级的是吧？！',
#   '-4'],
#  ['6981', '185', '2015/5/8', '1', '跳动de企鹅', '应该这个意思~', '-4'],
#  ['6981',
#   '186',
#   '2015/5/7',
#   '0',
#   'l***b',
#   '为什么除了大可乐，所有众筹的终身免费条款都这么含糊不清，免费升级到底是什么意思有什么其他条件：1、更换时间：每年，还是多久？2、更换方式：直接邮寄新品，还是需要寄回老品（如寄回旧款，旧款有何要求）？3、运送方式：产生的运费哪方承担？',
#   '-5'],
#  ['6981', '186', '2015/5/7', '1', '跳动de企鹅', '我没哟赶上大可乐要不我也弄一台了~', '-5'],
#  ['6981', '186', '2015/5/8', '1', '艾若', '艾玛说到大可乐3转眼已经半年过去啦，今年底拿新机！！', '-4'],
#  ['6981',
#   '187',
#   '2015/5/7',
#   '0',
#   'Archer宁',
#   '1、所谓的终身免费升级，指的是每次新款都直接快递给我们，还是我们用旧的置换；2、是一出新就直接寄给我们，还是时间随你们定，最迟延后多久？3、比如情侣款买了2个枕头，到时有新款了，是寄两个还是只是一个？',
#   '-5'],
#  ['6981', '187', '2015/5/7', '1', 'y***8', '是不是每次推出新品都免费升级？', '-5'],
#  ['6981', '188', '2015/5/8', '0', '逆天蝴蝶', '什么时间开始，快递用什么的', '-4'],
#  ['7116', '34', '2015/4/29', '0', '老方彬哥', '提前参与的可以早点收到产品吗？', '-5'],
#  ['7116', '35', '2015/4/29', '0', 'i***w', '具体什么时间点开始，跟其他竞品相比优势在哪。', '-5'],
#  ['7239', '13', '2015/4/12', '0', 'Z***聪', '这么好的产品必须顶，什么时候开放众筹阿？', '-1'],
#  ['7239',
#   '14',
#   '2015/4/12',
#   '0',
#   '晓***0',
#   '什么时间开始众筹？ps.第一个支持你们的要不要给个惊喜之类的',
#   '-1'],
#  ['7369', '146', '2015/4/27', '0', '133*****655', '研究点有用的，不切实际，异想天开……', '-1'],
#  ['7369', '147', '2015/4/26', '0', '老好人2013', '转接头派什么用处？可以手机给手机充电吗？', '-2'],
#  ['7369',
#   '148',
#   '2015/4/26',
#   '0',
#   'jove0916',
#   '大家注意看前面的评论，别被这些垃圾刷屏蒙蔽双眼',
#   '-2'],
#  ['7369',
#   '149',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身',
#   '-2'],
#  ['7369',
#   '150',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身',
#   '-2'],
#  ['7369',
#   '151',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~',
#   '-2'],
#  ['7369',
#   '152',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~',
#   '-2'],
#  ['7369',
#   '153',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~',
#   '-2'],
#  ['7369',
#   '154',
#   '2015/4/26',
#   '0',
#   'a***1',
#   '速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~ 速度发动身边的力量一起支持吧。 真心不错的小物件！~',
#   '-2'],
#  ['7369', '155', '2015/4/26', '0', 'c***3', '这个产品好 用起相当巴适', '-2'],
#  ['7369', '156', '2015/4/26', '0', 'c***3', '就说这个产品好用起很巴适', '-2'],
#  ['7369', '157', '2015/4/26', '0', '陈燏', '当然不错， 实用方便快捷。！ 难得的小物件。值得购买。', '-2'],
#  ['7369', '158', '2015/4/25', '0', 'jd_7bab632ea2857', '看着好像不错的样子', '-3'],
#  ['7369', '159', '2015/4/26', '0', '大***的', '灯光是白色的还是黄色的？可以调节不？', '-2'],
#  ['7369', '160', '2015/4/26', '0', '滇***你', '好久可以买？', '-2'],
#  ['7369', '160', '2015/4/26', '1', '老好人2013', '29日是周三啊', '-2'],
#  ['7369',
#   '161',
#   '2015/4/25',
#   '0',
#   '滇***你',
#   '看图片感觉还靠谱，不知实物和图片有多大差别？靠谱吗？',
#   '-3'],
#  ['7369',
#   '161',
#   '2015/4/25',
#   '1',
#   'jove0916',
#   '去众筹网看看，前面的评论有链接，两个项目产品应该是一个模样的',
#   '-3'],
#  ['7369', '162', '2015/4/26', '0', '喜***孩', '什么时候上线？买一根试试呢', '-2'],
#  ['7369', '163', '2015/4/26', '0', '喜***孩', '个人觉得还算行吧！又是灯又是线的', '-2'],
#  ['7369',
#   '164',
#   '2015/4/25',
#   '0',
#   '大旺堆cci',
#   '告别乱线如麻！很有诗意。楼下20元买两条充电线，充电时手机会不会爆炸啊？',
#   '-3'],
#  ['7369',
#   '164',
#   '2015/4/27',
#   '1',
#   '楓***公',
#   '各种大牌子数据线经常打折，所以你放心不会爆炸，例如羽博，小米，品胜等数据线都很靠谱，他们的名气比这个不知道哪里冒出来的高太多，这个都能充电，那他们肯定没问题',
#   '-1'],
#  ['7369', '165', '2015/4/26', '0', '格***年', '充电时，灯会一直亮吗？', '-2'],
#  ['7369', '166', '2015/4/25', '0', '军***9', '赞', '-3'],
#  ['7369',
#   '167',
#   '2015/4/25',
#   '0',
#   '楓***公',
#   '确实还不如京东买个9.9纯照明的，剩下20元还可以买2条充电线。这种充电还要拔盖子，很容易把盖子弄丢了，29元的价格也一点称不上众筹，而且竟然还是买越多价格越低，又不是商家，谁没事一个人会买这么多，最鄙视这种众筹方式。',
#   '-3'],
#  ['7369',
#   '168',
#   '2015/4/24',
#   '0',
#   '_Fay3809989',
#   '我觉得很实用，灯光也很不错，省电，晚上一人在家睡觉再也不用怕了。',
#   '-4'],
#  ['7369',
#   '169',
#   '2015/4/24',
#   '0',
#   'jove0916',
#   '送的转接头连图片都没有，别到时候给大家那种黑色的糙货，大家去众筹网看看评论就知道，这个项目做得多么的差劲，以下是链接：http://www.zhongchou.cn/deal-show/id-81055#maodian',
#   '-4'],
#  ['7369',
#   '170',
#   '2015/4/24',
#   '0',
#   'jove0916',
#   '我想问的是，为什么这个项目和歌奈在众筹网（http://www.zhongchou.cn/deal-show/id-81055#maodian）发起的一样，到底是谁抄谁的，难道没有专利的吗',
#   '-4'],
#  ['7369', '171', '2015/4/25', '0', 'shadow_long', '京东特价9.9，我还不如直接去买三个', '-3'],
#  ['7369',
#   '171',
#   '2015/4/25',
#   '1',
#   '楓***公',
#   '确实还不如买个9.9纯照明的，剩下20元还可以买2条充电线。这种充电还要拔盖子，很容易把盖子弄丢了，价格也一点称不上众筹，而且还是买越多价格越低，最鄙视这种众筹方式。',
#   '-3'],
#  ['7369', '172', '2015/4/24', '0', 'n***h', '看上去挺实用，线长也刚好，还能当灯用不错，期待一下', '-4'],
#  ['7369',
#   '173',
#   '2015/4/24',
#   '0',
#   '左右159bxo',
#   '好牛的设计，一看就知道是和我一样的天才设计出来的天才产品。很和我胃口。要是我就会在设计一下，戴在手腕上做装饰品。',
#   '-4'],
#  ['7369',
#   '174',
#   '2015/4/24',
#   '0',
#   'jd_stev972',
#   '好东西啊，科技改变生活，再也不用担心手机没电了。',
#   '-4'],
#  ['7369', '174', '2015/4/24', '1', 'jd_stev972', 'duangduangduang', '-4'],
#  ['7369', '174', '2015/4/24', '1', 'jd_stev972', 'duang', '-4'],
#  ['7369', '175', '2015/4/24', '0', '拓玛TOMA', '这个东西真正好，比小米那个安逸[憨笑]', '-4'],
#  ['7369', '176', '2015/4/24', '0', 'sonny1016', '赞一个！比小米更有创意', '-4'],
#  ['7369',
#   '177',
#   '2015/4/24',
#   '0',
#   'UP_1016',
#   '可以接在USB充电头上，插在接线板上给手机充不？',
#   '-4'],
#  ['7369', '178', '2015/4/24', '0', 'JD京致衣橱', '有创意 什么时候开卖', '-4'],
#  ['7369', '179', '2015/4/24', '0', '韬***纪', '终身免费换新是怎么换的？', '-4'],
#  ['7369', '180', '2015/4/24', '0', '子***哥', '这个保好久？', '-4'],
#  ['7369',
#   '181',
#   '2015/4/24',
#   '0',
#   '卡布奇诺820',
#   '前几天才买了一根小米LED灯，就只是灯，这个还可以充电，后悔了',
#   '-4'],
#  ['7369',
#   '181',
#   '2015/4/24',
#   '1',
#   'sonny1016',
#   '不知道雷军怎么想的，小米LED灯没有充电功能，令人费解啊',
#   '-4'],
#  ['7369',
#   '182',
#   '2015/4/24',
#   '0',
#   '快乐随身带',
#   '最下面的图片，安卓和苹果接口的图片弄反了，给你32个赞！哈哈',
#   '-4'],
#  ['7369', '182', '2015/4/24', '1', '卡布奇诺820', '哈哈哈！确实，粗心大意。[偷笑]', '-4'],
#  ['7369', '183', '2015/4/24', '0', 'kirazd', '图片上的安卓接口和图片接口都标反了', '-4'],
#  ['7369', '183', '2015/4/24', '1', '丸越', '你还敢买么？很不严谨啊.', '-4'],
#  ['7369', '184', '2015/4/24', '0', '风细雨轩', '看起来很棒，赞[太阳]', '-4'],
#  ['7369', '185', '2015/4/24', '0', '风细雨轩', '看起来很棒，赞[太阳]', '-4'],
#  ['7369', '186', '2015/4/24', '0', 'bzcwj', '创意不错。。。支持', '-4'],
#  ['7369', '187', '2015/4/24', '0', '成都向上', '这个是不是既可以当灯使用，又可以当数据线？[疑问]', '-4'],
#  ['7369', '188', '2015/4/24', '0', '逆天蝴蝶', '不错哦快递是发什么快递', '-4'],
#  ['7502',
#   '26',
#   '2015/4/13',
#   '0',
#   'b***0',
#   '支持这个众筹有效期是多久，近期没有保养的计划，麻烦确认一下有效期',
#   '-1'],
#  ['7502',
#   '27',
#   '2015/4/13',
#   '0',
#   'w***5',
#   '想问一下，奔驰E350可以参加吗？刚好快到保养的时间了，如果可以请回复，谢谢',
#   '-1'],
#  ['7502',
#   '28',
#   '2015/4/13',
#   '0',
#   'jd_113798945',
#   '我家就在和谐武汉店旁边，是一家豪华维修中心',
#   '-1'],
#  ['7502',
#   '29',
#   '2015/4/13',
#   '0',
#   'jd_轩辕紫箫',
#   '前两天刚去奥迪4S店保养1200多还是做活动价格，这个价格比4S店便宜多了',
#   '-1'],
#  ['7502', '30', '2015/4/11', '0', 'jd_815588275', '有没有联系方式！我有更好的项目可以合作', '-3'],
#  ['7502',
#   '32',
#   '2015/4/10',
#   '0',
#   '东东信龙卡',
#   '奥迪宝马和奔驰？！有钱人不在乎这点保养钱，你们来错地方了！',
#   '-4'],
#  ['7502',
#   '32',
#   '2015/4/10',
#   '1',
#   'jd_风儿伤',
#   '亲，其实任何品牌的车主都有参加、选择、支持或反对此次保养众筹的权利！虽然品牌不同，但是，认真选择、正确判断、都是我们消费者对众筹项目应有的贡献！感谢您的参与！',
#   '-4'],
#  ['7502',
#   '34',
#   '2015/4/9',
#   '0',
#   'j***8',
#   '这价格，比4s店便宜点，比普通汽车店贵一点。上海也就那么一家，那么偏，跑那么远，谁有空的。',
#   '-5'],
#  ['7598', '99', '2015/4/25', '0', '沙鳅', '这个鱼探仪抛到水面后怎么收回来呢？', '-2'],
#  ['7598',
#   '99',
#   '2015/4/25',
#   '1',
#   'jd_156922bbs',
#   '那就是另外再准备根鱼线，垂钓结束后后用鱼线拉回喽',
#   '-2'],
#  ['7598', '100', '2015/4/24', '0', '好价格好心情', 'APP 有安卓的吗？介绍里的二维码是IOS的。', '-3'],
#  ['7598', '101', '2015/4/23', '0', '陈大大爷', '啥时候上线', '-4'],
#  ['7598', '102', '2015/4/23', '0', '桥哥哟', '人与鱼之间最基本的信任也没了。', '-4'],
#  ['7598',
#   '103',
#   '2015/4/23',
#   '0',
#   'jd_惟妮宝',
#   '挺漂亮的样子，什么时候卖啊？老公喜欢钓鱼给他买一个。',
#   '-4'],
#  ['7598',
#   '104',
#   '2015/4/22',
#   '0',
#   '以马',
#   '靠手杆抛，杆都能承受吗？能承受我是不是还要单独线，要几点零的线更安全些，你这东西标价300多配备为什么不全一点，至于理论能探测水深15，蓝牙范围150，还得有东西，才能确定，我是做IT的，也是钓鱼爱好者。希望能给回复，很想体验一下，还是蛮期待的。',
#   '-5'],
#  ['7598', '105', '2015/4/21', '0', 'zhenghan39', '东西很不错啊！！！我一定会买的', '-6'],
#  ['7598', '106', '2015/4/21', '0', '1***2', '平时等的烦躁啊   正缺少这样一个宝贝', '-6'],
#  ['7598', '107', '2015/4/21', '0', 'illushive', '好高大上啊，能连上什么手机哟？', '-6'],
#  ['7598', '108', '2015/4/21', '0', '黑***月', '看上去可以，不知道东西怎样，真能探到么？', '-6'],
#  ['7691', '98', '2015/5/7', '0', 'SamirXu', '请问可以自己装应用嘛?', '-1'],
#  ['7691', '100', '2015/5/6', '1', 'Rockben', '支持电视直播的，好期待他给爸妈发视频的功能', '-2'],
#  ['7691', '101', '2015/5/6', '1', 'Rockben', '里面不是写了4核么', '-2'],
#  ['7691', '102', '2015/5/6', '0', '任****', '什么时间开始', '-2'],
#  ['7698',
#   '156',
#   '2015/6/5',
#   '0',
#   'l***p',
#   '基于OBD接口的设备基本分为两类，一种是车载诊断，另一种是实现后视镜自动折叠和自动关窗的，如果能把这两者结合起来会更有卖点~因为OBD接口只有1个，而对于很多车主来说后视镜折叠和关窗更为实用~',
#   '-3'],
#  ['7698', '157', '2015/6/5', '0', 'j***a', '[太阳]', '-3'],
#  ['7698',
#   '158',
#   '2015/6/5',
#   '1',
#   's***g',
#   '优秀产品，值得期待，等产品测试下[真棒][真棒][真棒]',
#   '-3'],
#  ['7725', '9', '2015/10/28', '0', '天王星刘', '真是好东东，上线了一定来买一台，请问可以上门安装吗？', '-2'],
#  ['7725', '10', '2015/10/28', '0', 'hedyboy', '真好，就是买不起。', '-2'],
#  ['7747', '36', '2015/5/2', '0', '烟***0', '这也能众筹，是不是库存的产品就上京东众筹', '-2'],
#  ['7747',
#   '37',
#   '2015/5/1',
#   '0',
#   't***d',
#   '建议三：这文案实在是有点烂。大家关心的组成和功能，不一一说明，却选了几张搭配很丑的图片。比如那张电视墙的左上角，难看，而且是准备作鸟窝用吗&hellip;&hellip;',
#   '-3'],
#  ['7747',
#   '38',
#   '2015/5/1',
#   '0',
#   't***d',
#   '建议二：目前设计的时钟有点鸡肋，建议干脆就设计成温湿度计，这样进门的时候可以看看潮不潮。以后升级的时候，可以改为香薰或者空气清新剂。',
#   '-3'],
#  ['7747', '38', '2015/5/1', '1', '中融鼎邦', '期待你八月份入手后的回评', '-3'],
#  ['7747',
#   '38',
#   '2015/5/1',
#   '1',
#   't***d',
#   '忘了说，众筹开始的时候我肯定会来买的（只要99的有货）。[偷笑]',
#   '-3'],
#  ['7747',
#   '39',
#   '2015/5/1',
#   '0',
#   't***d',
#   '建议一：目前的设计比micklish更实用大方，挂钩很实用，颜色也更多样。但目前选择的几种艳丽的颜色明显拉低了产品档次，试想谁家装修会选择最鲜艳的这种粉黄绿蓝呢？太出租房的感觉了。倒不如专心研究木质的配色和产品的设计，甚至提供不锈钢的材质选择，有3种选择就可以了。',
#   '-3'],
#  ['7747',
#   '39',
#   '2015/5/1',
#   '1',
#   't***d',
#   '挂钩毕竟是可以取下来的，而且实用性不错。鲜艳的颜色把木质直接弄出塑料的感觉了，不知道女孩子的需求是不是这样。虽然金属也许会有点冷，但iphone、macbook一直卖得很好啊',
#   '-3'],
#  ['7747',
#   '39',
#   '2015/5/1',
#   '1',
#   '中融鼎邦',
#   '再仔细多看看话题区顶上图片中的挂钩。。。不觉得和几种艳丽的颜色一样明显拉低了产品档次？o(&cap;_&cap;)o',
#   '-3'],
#  ['7747', '40', '2015/5/1', '0', 'TCL甜甜', '这东西好不好装的？', '-3'],
#  ['7747',
#   '40',
#   '2015/5/1',
#   '1',
#   'TCL甜甜',
#   '感谢您的关注！随产品包装，我们会配置安装螺丝及安装说明，在设计好的螺丝孔上，用一把螺丝批就可以方便固定地在木板（门板）上；如果要安装在水泥墙上，你可能需要借用电动钻子，在墙上先打好孔。还有一种最简单的安装方法，可以用一根绳子穿过2个小孔，挂在任何已有的钉子或钩子上即可。',
#   '-3'],
#  ['7747',
#   '41',
#   '2015/5/1',
#   '1',
#   't***d',
#   '我觉得比micklish那个设计更实用大方啊。仔细看了一下，micklish的时间是靠手机来实现的，不仅手机尺寸不能太大不能太小，而且谁会把回家要充电的手机放那里。另外，设计的挂钩也很实用。',
#   '-3'],
#  ['7747', '41', '2015/5/1', '1', '艾若', '孔乙己：&ldquo;读书人的偷能叫偷吗？&rdquo;', '-3'],
#  ['7747',
#   '42',
#   '2015/5/1',
#   '0',
#   '某yin',
#   '大小高度，小东西不描述怎么摆放，能放哪些，怎么固定都没有谁会感兴趣。看了一圈就知道这不知道干啥的东西，有多种颜色名字上也没搞懂是带出去的还是摆在门口的',
#   '-3'],
#  ['7747', '42', '2015/4/28', '1', 'b***q', '大小跟一张A4纸一样大。', '-6'],
#  ['7747', '42', '2015/4/28', '1', '艾若', '乍看标题我也以为是出差用的收纳盒......', '-6'],
#  ['7775', '45', '2015/5/3', '0', '东***技', '咋的，抢钱呢，上次众筹的一款还不到千元，有可能失败哦', '-1'],
#  ['7775', '45', '2015/5/3', '1', '东***技', '不过，还是预祝能成功!', '-1'],
#  ['7775',
#   '47',
#   '2015/4/29',
#   '0',
#   'a***n',
#   '请问屏幕是在后视镜的中间位置，开机状态下，会不会对观察车后情况有影响哦？支持奥迪A4L 2015款吗？成都市有无安装地点？',
#   '-5'],
#  ['7775',
#   '50',
#   '2015/4/29',
#   '0',
#   '那爱很美爱你没商量',
#   '想问1、奥迪Q3 2013舒适型可否定制?2、包安装吗？3、上海地区可有安装地点？',
#   '-5'],
#  ['7775', '51', '2015/4/29', '0', 'jd_路基', '可能会失败', '-5'],
#  ['7775', '52', '2015/4/28', '0', '丸越', '2000多不如直接买个内置导航了，比这个实用.', '-6'],
#  ['7775', '54', '2015/4/28', '0', 'nyghbj', '东西不错，但这价格高啊。', '-6'],
#  ['7775', '55', '2015/4/28', '0', 'bzcwj', '和其他众筹的产品差不多，不足：需要流量卡、价格过高。', '-6'],
#  ['7944', '89', '2015/5/13', '0', '箜空控', '除了太阳能给内置电池充电 ，可以线充么？', '-1'],
#  ['7944', '90', '2015/5/12', '0', 'jove0916', '没太阳怎么办', '-2'],
#  ['7944',
#   '91',
#   '2015/5/10',
#   '0',
#   'z***q',
#   '单晶硅还是多晶硅，避而不谈，转换率顾左右而言他，什么产品呀？',
#   '-4'],
#  ['7944', '93', '2015/5/10', '0', 'z***q', '太阳能转换效率多少？', '-4'],
#  ['7944', '94', '2015/5/9', '0', '夏***侣', '怎么不理我？双休日也得理睬一下我吧', '-5'],
#  ['7944', '95', '2015/5/9', '0', '夏***侣', '你们能不能送我一条啊，买一送一，来一个新选项？', '-5'],
#  ['7944',
#   '96',
#   '2015/5/9',
#   '0',
#   '夏***侣',
#   '挺好玩的东东，我比较过数据，好像你们这块的功率比一般的太阳能充电要高，有没有白色的啊？',
#   '-5'],
#  ['7944',
#   '97',
#   '2015/5/8',
#   '0',
#   '快乐随身带',
#   '太粗了，也不好看，起码看图片上的不好看。。。环保是不错，但没有我用移动电源来得实在',
#   '-6'],
#  ['7944',
#   '98',
#   '2015/5/8',
#   '0',
#   '裱花奇笔',
#   'TB众筹看着都很烂，你们到那去发布过难道。。。不行吧，兄弟。',
#   '-6'],
#  ['7944',
#   '99',
#   '2015/5/8',
#   '0',
#   '裱花奇笔',
#   '这货什么时候上线，我可能想买两根背带，窜个包，便宜点行不？？看你们讨论，两条背带就是6W，那效率挺高，能给电脑充电不？还有ipad,照相机，一起搞起？',
#   '-6'],
#  ['7944',
#   '100',
#   '2015/5/8',
#   '0',
#   'm***n',
#   '我个人是学习环境工程专业的，对环保新能源产品一直在关注，确定是3W的太阳能面板么，2个1.5W？？',
#   '-6'],
#  ['7944',
#   '100',
#   '2015/5/8',
#   '1',
#   'm***n',
#   '类似产品在TB还是挺多，不过骂的也多，还是效率问题，充的时间太长成摆设',
#   '-6'],
#  ['7944',
#   '101',
#   '2015/5/8',
#   '0',
#   'WofanIncu',
#   '而且太阳能充电背包比较环保，你们这个背带还有其他颜色吗？？',
#   '-6'],
#  ['7944',
#   '102',
#   '2015/5/8',
#   '0',
#   'WofanIncu',
#   '很不错的设计，以后出去旅游或者Hiking的时候可以应急使用了。什么时候上线？',
#   '-6'],
#  ['7944',
#   '103',
#   '2015/5/8',
#   '0',
#   'm***n',
#   '名字叫快充，但是10-14点的太阳也就200-300MA电流，和现在的1A和2A输入比起来，你这都10年前的标准了，快在哪里，希望改进，我们需要5W的，但是外观如何是你们自己的事情了，折叠？还是提高效率',
#   '-6'],
#  ['7944', '105', '2015/5/8', '0', '惑天', '很好的创意！', '-6'],
#  ['7944', '106', '2015/5/8', '0', '问_路', '上架时间是什么时候？', '-6'],
#  ['7980', '32', '2015/5/26', '0', 'jdhappyhbgu', '净水器买回来后,怎么安装', '-8'],
#  ['7980', '33', '2015/5/25', '0', 'yhewioty', '带不带储水罐的', '-9'],
#  ['7980', '34', '2015/5/25', '0', 'Val_Kyrie', '不错~支持下', '-9'],
#  ['7980', '35', '2015/5/25', '0', '小***哼', '滤芯多久换一次，成本高不高[疑问]', '-9'],
#  ['7980',
#   '36',
#   '2015/5/23',
#   '0',
#   'x***o',
#   '看着还不错，不用电的是吧？现在家里有个用电的纯水机觉得不好，所以想换了',
#   '-11'],
#  ['7980',
#   '40',
#   '2015/5/23',
#   '0',
#   'h***u',
#   '想了解一下过滤后的水在口感上会不会有变化?安装一般是安装在哪里的?还有在装修的时候需要预先留管的吗',
#   '-11'],
#  ['7980', '41', '2015/5/23', '0', 'jd_bjlz0', '质量刚刚的！', '-11'],
#  ['7980',
#   '42',
#   '2015/5/22',
#   '0',
#   'jdzeake',
#   '这款净水器价格比较合理，性价比也挺高的，期待上线。',
#   '-12'],
#  ['7980', '43', '2015/5/22', '0', '186*****184_p', '你这是矿物质水，还是纯水？', '-12'],
#  ['7980', '45', '2015/5/22', '0', 'n***5', '现在净水器的价格相差很大，你的为什么是这个价格。', '-12'],
#  ['7980',
#   '46',
#   '2015/5/21',
#   '0',
#   'bzcwj',
#   '问下，每个滤芯的更换成本是多少、。这是必须关注的地方',
#   '-13'],
#  ['7980',
#   '46',
#   '2015/5/21',
#   '1',
#   'hell7843',
#   '那都能看见你这鼎美水军，你是不是傻逼淘气三千问？[憨笑]',
#   '-13'],
#  ['8019', '198', '2015/4/22', '0', 'rz090917', '很不错的感觉', '-1'],
#  ['8019', '199', '2015/4/22', '0', '利***D', '明天终于上线了', '-1'],
#  ['8019',
#   '200',
#   '2015/4/22',
#   '0',
#   'jd_______',
#   '[玫瑰][玫瑰][玫瑰]感觉蛮不错嘚样子.期待ing...',
#   '-1'],
#  ['8019',
#   '201',
#   '2015/4/22',
#   '0',
#   '181*****925_p',
#   '看起来不错，灰常好。有句话说到：当今社会，出门在外，身上可以没钱，但不可以没电。就是你了，宝贝^_^',
#   '-1'],
#  ['8019', '201', '2015/4/22', '1', 'callmeanna', '看起来不错，期待[太阳][太阳][太阳]', '-1'],
#  ['8019', '202', '2015/4/22', '0', '小***o', '看起来感觉还不错。 盯上了！！', '-1'],
#  ['8019', '203', '2015/4/22', '0', '晴***Q', '很不错的感觉。', '-1'],
#  ['8019', '204', '2015/4/22', '0', 'jd_ccf/微笑', '好，准备好网络明天开抢！', '-1'],
#  ['8019', '205', '2015/4/22', '0', 'qiu8472', '期待中', '-1'],
#  ['8019', '206', '2015/4/22', '0', '158*****005', '良心品牌绝对支持。[玫瑰]', '-1'],
#  ['8019', '207', '2015/4/22', '0', '梦***裳', '[难过]我找了好久、期待', '-1'],
#  ['8019',
#   '208',
#   '2015/4/22',
#   '0',
#   'ckc135*****991',
#   '看了，不错。已经准备好信用卡了，准备抢点货回来!',
#   '-1'],
#  ['8019', '209', '2015/4/22', '0', '晴***Q', '很不错。期待[可爱]', '-1'],
#  ['8019',
#   '210',
#   '2015/4/22',
#   '0',
#   'jd259329cjo',
#   '[真棒]支持一个，期待着[偷笑][偷笑]',
#   '-1'],
#  ['8019', '211', '2015/4/22', '0', 'jd181771odi', '挺不错的', '-1'],
#  ['8019', '212', '2015/4/22', '0', '穷人不是罪', '什么时候开始呀', '-1'],
#  ['8019', '213', '2015/4/21', '0', 'W***长', '我也来支持下美女', '-2'],
#  ['8019', '214', '2015/4/21', '0', '185*****363凤', '买了很多移动电源 希望这款是良心产品', '-2'],
#  ['8019', '215', '2015/4/21', '0', '183*****750_p', '[害羞]', '-2'],
#  ['8019', '216', '2015/4/21', '0', 'qiu8472', '什么时候上市？', '-2'],
#  ['8019', '217', '2015/4/21', '0', 'c***9', '好像2很好的样子，到时候也来抢个吧！', '-2'],
#  ['8019', '218', '2015/4/21', '0', 'qiu8472', '我也想要一个[害羞]', '-2'],
#  ['8019', '219', '2015/4/22', '0', '哈黑哈122', '我的oppo手机能快冲吗', '-1'],
#  ['8019', '219', '2015/4/22', '1', '穷人不是罪', '我滴手机不知道能不能支持快冲[疑问]', '-1'],
#  ['8019', '220', '2015/4/21', '0', '肖***4', '到时一定要抢个', '-2'],
#  ['8019', '221', '2015/4/21', '0', 'jd134161ezs', '期待……', '-2'],
#  ['8019', '222', '2015/4/21', '0', '杨***权', '老板级的充电宝，很不错！', '-2'],
#  ['8019', '223', '2015/4/21', '0', '138*****615_p', '[奸笑]', '-2'],
#  ['8019', '224', '2015/4/21', '0', 'linda151*****023', '期待', '-2'],
#  ['8019', '225', '2015/4/21', '0', '周***丽', '期待中', '-2'],
#  ['8019', '226', '2015/4/21', '0', 'qiu8472', '期待中，，，', '-2'],
#  ['8019', '227', '2015/4/21', '0', 'jd_135367nvq', '支持[握手]', '-2'],
#  ['8019', '228', '2015/4/21', '0', 'h***2', '流量真的有那么大吗', '-2'],
#  ['8019', '229', '2015/4/21', '0', 'X***0', '支持[握手]', '-2'],
#  ['8019', '229', '2015/4/21', '1', 'jd_742469148', '十分支特', '-2'],
#  ['8019', '230', '2015/4/21', '0', '138*****615_p', '[太阳]', '-2'],
#  ['8019',
#   '231',
#   '2015/4/21',
#   '0',
#   'jd_156186lkm',
#   '等待[太阳][太阳][太阳][太阳][太阳]',
#   '-2'],
#  ['8019', '232', '2015/4/21', '0', '135*****630_p', '支持[握手]', '-2'],
#  ['8019', '233', '2015/4/20', '0', '137*****151_p', '有这么好吗', '-3'],
#  ['8019',
#   '234',
#   '2015/4/20',
#   '0',
#   '哈黑哈122',
#   '你不会是把1万毫安会或者15000毫安显示成20000毫安吧   如果不作假 还那可以接受',
#   '-3'],
#  ['8019',
#   '235',
#   '2015/4/20',
#   '0',
#   'C***8',
#   '之前用过你家的名片式充电宝感觉还可以，不知道这款怎么样，支持158入一个试一下。',
#   '-3'],
#  ['8019', '236', '2015/4/20', '0', '不懂321', '真的很不错，不买就太可惜了', '-3'],
#  ['8019', '237', '2015/4/20', '0', '不懂321', '23号23号  快快到来吧', '-3'],
#  ['8019',
#   '238',
#   '2015/4/20',
#   '0',
#   'w***6',
#   '如果我想达到2A以上的输入输出，是不是一定要用这个2.5A快充适配器和数据线？为什么不是3.5A的，如果我想达到3.5A的输出该怎么做呢？',
#   '-3'],
#  ['8019', '239', '2015/4/20', '0', 'X***0', '期待23号快点来吧。。。', '-3'],
#  ['8019',
#   '240',
#   '2015/4/20',
#   '0',
#   'tangyan321',
#   '期待中，，，，一天看好几次，还是看不够啊！',
#   '-3'],
#  ['8019',
#   '241',
#   '2015/4/20',
#   '0',
#   'j***3',
#   '吼吼吼，给很多人看了都说不错，快点到23号吧，要下手啦    哈哈哈哈哈',
#   '-3'],
#  ['8019', '242', '2015/4/20', '0', '183*****981_p', '质量很好。性价比很高[太阳]', '-3'],
#  ['8019', '243', '2015/4/20', '0', 's***9', '看着还不错，期待～～', '-3'],
#  ['8019', '244', '2015/4/20', '0', 'l***7', '高端大气', '-3'],
#  ['8019', '245', '2015/4/20', '0', '利***D', '歁负我没有用过移动电源是吧？哪有这么大的输出毫安啊', '-3'],
#  ['8019', '246', '2015/4/20', '0', 'X***0', '价格是不是有点高啊？不过睇上去仲系几靓下', '-3'],
#  ['8019', '247', '2015/4/20', '0', '摘星追梦', '[真棒]感觉很不错，期待中', '-3'],
#  ['8019',
#   '248',
#   '2015/4/20',
#   '0',
#   '135*****124_p',
#   '一直关注很久了 外贸出口的 经常出差所以很需要[太阳]',
#   '-3'],
#  ['8019', '249', '2015/4/20', '0', '7***m', '希望不要让消费者们失望了[握手]', '-3'],
#  ['8019', '250', '2015/4/20', '0', 'RRDgZubmnjwC', '支持158', '-3'],
#  ['8019', '252', '2015/4/20', '0', '865972880', '能一边给充电宝充电，再用充电宝给手机充电？', '-3'],
#  ['8019', '253', '2015/4/19', '0', 'jd_138232mii', '加油！非常棒', '-4'],
#  ['8019', '254', '2015/4/19', '0', 'jd903544', '19999mAh值得期待！', '-4'],
#  ['8019', '255', '2015/4/19', '0', '赵***寿', '很适合我，不错！[真棒]', '-4'],
#  ['8019', '256', '2015/4/19', '0', 'jd137128ljp', '太好了', '-4'],
#  ['8019', '257', '2015/4/19', '0', 'jd_阿源', '看样子不错', '-4'],
#  ['8019',
#   '258',
#   '2015/4/19',
#   '0',
#   'jd_138232mii',
#   '非常棒，我用过这个公司产品质量价格性价比超高！',
#   '-4'],
#  ['8019', '259', '2015/4/18', '0', 'jd_138266vna', '时刻关注着', '-5'],
#  ['8019', '260', '2015/4/18', '0', 'jiangxintang12306', '有时间会经常来的', '-5'],
#  ['8019', '261', '2015/4/19', '0', 'qiu8472', '关注中', '-4'],
#  ['8019',
#   '262',
#   '2015/4/18',
#   '0',
#   'jd_╰Esc__·╮坚强',
#   '支持者每人发一台体验一下那就好了，嘿嘿',
#   '-5'],
#  ['8019', '263', '2015/4/18', '0', 'tangyan321', '时刻关注着，，，', '-5'],
#  ['8019',
#   '264',
#   '2015/4/18',
#   '0',
#   '桃***2',
#   '价格有点小贵，和小米啊那些品牌的充电宝差不多了，它有什么优势？',
#   '-5'],
#  ['8019',
#   '265',
#   '2015/4/19',
#   '0',
#   'j***3',
#   '[真棒]其实我就是想知道可不可以早点上线，要出门啊，要带充电宝啊，小的根本就不够用   哎...',
#   '-4'],
#  ['8019',
#   '266',
#   '2015/4/18',
#   '0',
#   '谁***字',
#   '高端大气上档次，低调奢华有内涵。      期待上线。[真棒]',
#   '-5'],
#  ['8019', '267', '2015/4/18', '0', '时光伴侣', '容量是实标的吗，很高端，期待上线', '-5'],
#  ['8019',
#   '268',
#   '2015/4/18',
#   '0',
#   'X***0',
#   '8小时可以充满充电宝 ？ Iphone真的可以充10次？',
#   '-5'],
#  ['8019', '269', '2015/4/18', '0', '181*****887_p', '好 很好', '-5'],
#  ['8019', '270', '2015/4/19', '0', 'jd_花非花', '美国微芯求解求爱求关注！', '-4'],
#  ['8019', '271', '2015/4/18', '0', 'jd189900eox', '期待期待', '-5'],
#  ['8019', '272', '2015/4/19', '0', 'C***8', '众筹结束后是多少钱一个？', '-4'],
#  ['8019', '272', '2015/4/19', '1', 'handsome13', 'TB有售。188 加送一禮品。', '-4'],
#  ['8019', '273', '2015/4/18', '0', '杜***学', '很期待哦  快出来吧', '-5'],
#  ['8019', '274', '2015/4/18', '0', '131*****121_p', '期待中！！', '-5'],
#  ['8019',
#   '275',
#   '2015/4/18',
#   '0',
#   'C***8',
#   '容量真的有20000毫安吗？现在网上好多虚标的，买一个10000毫安的，两次都充不到就没电了。',
#   '-5'],
#  ['8019', '276', '2015/4/18', '0', '涂巧7426', '这么高大上的宝贝，值得拥有！', '-5'],
#  ['8019', '277', '2015/4/18', '0', 'jd158813vpj', '[真棒]', '-5'],
#  ['8019', '278', '2015/4/18', '0', '桃***2', '楼主，肿么不回复我滴问题？', '-5'],
#  ['8019',
#   '279',
#   '2015/4/18',
#   '0',
#   'jd_刃儿',
#   '哇，看起来好精致哦，高端大气上档次，超大容量，功能强大，外出携带再也不担心手机没电了，期待上线，值得拥有！',
#   '-5'],
#  ['8019',
#   '280',
#   '2015/4/18',
#   '0',
#   'X***0',
#   '期待中上线  这么大容量 去哪里再也不担心手机没有电了',
#   '-5'],
#  ['8019', '281', '2015/4/18', '0', '石泉2015', '看起来挺高逼格的，赞一个，关注下，期待上线！', '-5'],
#  ['8019', '282', '2015/4/18', '0', '利***D', '充电真的有这么快？', '-5'],
#  ['8019', '283', '2015/4/18', '0', 'tangyan321', '会不会很大啊！求，，，，', '-5'],
#  ['8019', '284', '2015/4/18', '0', 'qiu8472', '价格是不是有点高啊？不过睇上去仲系几靓下', '-5'],
#  ['8019', '285', '2015/4/18', '0', 'qiu8472', '啥时候上线啊，感觉挺高档啊', '-5'],
#  ['8019', '286', '2015/4/18', '0', 'jd_阿源', '啥时候上线啊，感觉挺高档啊', '-5'],
#  ['8019', '287', '2015/4/18', '0', 'tangyan321', '感觉高端大气上档次，期待中，，，，，', '-5'],
#  ['8019', '288', '2015/4/18', '0', '瑞***店', '看着很不错，相信用起来会更好，期待中', '-5'],
#  ['8019', '289', '2015/4/18', '0', 'zhang135*****503', '看起来很不错的样子喔[真棒]', '-5'],
#  ['8019', '290', '2015/4/18', '0', 'c***9', '期待中.......', '-5'],
#  ['8019', '291', '2015/4/18', '0', 'jd_阿源', '期待中[可爱]', '-5'],
#  ['8019',
#   '292',
#   '2015/4/18',
#   '0',
#   'X***0',
#   '外观很靓丽，就是感觉有点厚的，重量是多少，方便携带吗',
#   '-5'],
#  ['8019',
#   '293',
#   '2015/4/18',
#   '0',
#   '清石泉',
#   '还有哦，电量那么大，安全吗？前段时间老听说充电宝爆炸。这个会不会不安全啊？有没有什么认证木有啊？',
#   '-5'],
#  ['8019',
#   '294',
#   '2015/4/18',
#   '0',
#   '清石泉',
#   '有多大的？我是说尺寸哦。转换率实际是多少呢？有木有那位大神出来解释下哈！小白一个呢',
#   '-5'],
#  ['8019', '295', '2015/4/18', '0', '桃***2', '精显是什么概念？[疑问]', '-5'],
#  ['8019', '296', '2015/4/18', '0', 'qiu8472', '感觉不错哦，到时候再看看', '-5'],
#  ['8019', '297', '2015/4/18', '0', 'jd491181aiz', '期待中[害羞]', '-5'],
#  ['8019',
#   '298',
#   '2015/4/18',
#   '0',
#   'y***c',
#   '这好东西，非常实用，电子屏显示很明了，手机、平板带出去就不愁没电了，大赞！',
#   '-5'],
#  ['8019',
#   '299',
#   '2015/4/18',
#   '0',
#   '花非花还是非花',
#   '5.1黄金周去玩带去挺好的，就是不知道那之前能不能拿到货呢？',
#   '-5'],
#  ['8019', '300', '2015/4/18', '0', '158*****751_p', '高大上[真棒]', '-5'],
#  ['8019', '301', '2015/4/18', '0', 'jd259329cjo', '期待中[太阳][太阳]', '-5'],
# ...
#  ['8997', '1518', '2015/4/9', '1', '极睿软件-DreamVR', '里面放置手机的~页面有介绍哦~', '-1'],
#  ['8997', '1519', '2015/4/9', '0', 'jd_187221ncb', '好期待，静等活动开始', '-1'],
#  ['8997', '1519', '2015/4/9', '1', '极睿软件-DreamVR', '多谢您的支持~！', '-1'],
#  ['8997',
#   '1520',
#   '2015/4/9',
#   '0',
#   'jd_原来是娃娃脸',
#   '很不错的项目，未来的游戏需要这些，软件技术硬件也需要资金，100多块钱不是很多就当是给未来游戏一个憧憬吧。',
#   '-1'],
#  ['8997', '1520', '2015/4/9', '1', '极睿软件-DreamVR', '非常感谢您的支持', '-1'],
#  ['8997',
#   '1521',
#   '2015/4/9',
#   '0',
#   'jd159017yzt',
#   '这个蓝牙手柄是通用型的，我用过，很不好用！你们就没有开发出一款像魔镜一样针对你们这款产品专用的蓝牙手柄吗？至少配个蓝牙游戏手柄也比这个强呀！',
#   '-1'],
#  ['8997', '1521', '2015/4/9', '1', '洛克菲勒-', '可以看电影吗？', '-1'],
#  ['8997',
#   '1521',
#   '2015/4/9',
#   '1',
#   '极睿软件-DreamVR',
#   '因为价格定位较低，因此没有办法配游戏手柄哦~您可以选购无手柄版本，再购买您想要的手柄来搭配DreamVR',
#   '-1'],
#  ['8997',
#   '1522',
#   '2015/4/9',
#   '0',
#   '福***0',
#   '手机放进去观看影片，对眼睛的保护没有说，会不会影响视力呢？还有就是音响输出是手机外放或耳机吗？蓝牙手柄除了支持本产品外也支持其他游戏的手玩吗？',
#   '-1'],
#  ['8997',
#   '1522',
#   '2015/4/9',
#   '1',
#   '极睿软件-DreamVR',
#   '光学级PMMA透镜，有效保护视力。但也不建议长时间使用DreamVR，音响输出可以外放，但更建议用户配合耳机使用~其他大部分手机蓝牙手柄也都可以支持的哦',
#   '-1'],
#  ['8997', '1523', '2015/4/9', '1', 's***r', '也就是说两眼屈光度不同，效果的就不行', '-1'],
#  ['8997',
#   '1523',
#   '2015/4/9',
#   '1',
#   '极睿软件-DreamVR',
#   '[可爱]左右度数较为接近的话是可以的哦[可爱]',
#   '-1'],
#  ['8997',
#   '1524',
#   '2015/4/8',
#   '0',
#   '动***游',
#   '和暴风魔镜有什么区别，如果没有亮点何必耽误时间去买一个众筹产品，回报周期长并且产品质量不确定',
#   '-2'],
#  ['8997',
#   '1524',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '从软件和硬件都和魔镜有较大差别，硬件在光学、视角方面，软件的交互设计与沉浸感。',
#   '-2'],
#  ['8997',
#   '1525',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '我们就是想要做出沉浸感强且性价比高的虚拟现实设备，效果非常沉浸，谢谢支持~',
#   '-2'],
#  ['8997', '1526', '2015/4/8', '0', 'jd156980jsx', '蓝牙手柄干什么用的', '-2'],
#  ['8997', '1526', '2015/4/8', '1', '极睿软件-DreamVR', '玩游戏更适合搭配蓝牙手柄', '-2'],
#  ['8997', '1526', '2015/4/8', '1', '姑娘能穿好衣服吗', '同问', '-2'],
#  ['8997', '1527', '2015/4/8', '0', 'jd_67d4921059d15', '支持  支持', '-2'],
#  ['8997', '1527', '2015/4/8', '1', '极睿软件-DreamVR', '多谢支持~', '-2'],
#  ['8997', '1528', '2015/4/8', '0', 'jd吴金nnu', '跟暴风魔镜貌似没啥区别', '-2'],
#  ['8997', '1528', '2015/4/8', '1', '极睿软件-DreamVR', '视角沉浸感和魔镜差别很大哦~', '-2'],
#  ['8997',
#   '1529',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '并且我们团队最初就是做虚拟现实应用游戏开发的，所以在这方面也较有优势~',
#   '-2'],
#  ['8997',
#   '1529',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '简单的原理可以这么理解呢！但是体验效果真的很沉浸~不同于市场上之前的产品呢~',
#   '-2'],
#  ['8997', '1530', '2015/4/8', '0', '哆啦小鱼', '周五几点上架？', '-2'],
#  ['8997', '1530', '2015/4/8', '1', '极睿软件-DreamVR', '预计中午12点~[可爱]', '-2'],
#  ['8997', '1531', '2015/4/8', '0', 'o夜未眠', '没有介绍是1080p还是720p还是别的啊', '-2'],
#  ['8997', '1531', '2015/4/8', '1', '极睿软件-DreamVR', '搭配手机使用，此参数依据手机屏幕参数', '-2'],
#  ['8997', '1532', '2015/4/8', '0', '哆啦小鱼', '不续费影院是否有免费片源和游戏？', '-2'],
#  ['8997', '1532', '2015/4/8', '1', '极睿软件-DreamVR', '有的[憨笑]', '-2'],
#  ['8997', '1533', '2015/4/8', '0', '哆啦小鱼', '会员结束后续费会员每年多少钱？', '-2'],
#  ['8997',
#   '1533',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '15元/月，不开通金会员也可以使用软件的大部分基础功能',
#   '-2'],
#  ['8997',
#   '1534',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '金会员会有一些增是服务特权，软件不开通金会员也是可以使用所有基本功能的。',
#   '-2'],
#  ['8997',
#   '1534',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '15元/月是暂定价格，金会员主要并不是服务于影片内容的，而是游戏内容。',
#   '-2'],
#  ['8997',
#   '1534',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '自己找的3D片都可以通过有梦影院本地版播放，有梦影院在线版会有一些特殊内容免费提供给DreamVR金会员。金会员续费价格15元/月。',
#   '-2'],
#  ['8997', '1535', '2015/4/8', '0', 'jd_171404762', '手机是可以放在眼睛里面的？', '-2'],
#  ['8997',
#   '1535',
#   '2015/4/8',
#   '1',
#   '极睿软件-DreamVR',
#   '对的，将手机放置在眼镜里面~而且我们的结构非常简单易用，操作很方便',
#   '-2'],
#  ['8997', '1535', '2015/4/8', '1', 'jd_171404762', '眼镜', '-2'],
#  ['8997', '1536', '2015/4/8', '0', 'Q***2', '什么时间开始', '-2'],
#  ['8997', '1536', '2015/4/8', '1', '极睿软件-DreamVR', '感谢您的关注！周五中午正式开始！', '-2'],
#  ['9054', '145', '2015/4/17', '0', 'j***n', '详细配置不能说说？', '-3'],
#  ['9054', '146', '2015/4/17', '0', 'z***x', '推T90怎么样？', '-3'],
#  ['9054', '147', '2015/4/17', '1', 'jd_9720623', '爱国电子怎么说', '-3'],
#  ['9054',
#   '147',
#   '2015/4/17',
#   '1',
#   '杀***汪',
#   '可以把您的耳机推得很好，您还可以匹配更高端的耳机获得更好地效果',
#   '-3'],
#  ['9054', '147', '2015/4/17', '1', 'jd_9720623', '我也有一个，等答复哦[疑问]', '-3'],
#  ['9054', '149', '2015/4/16', '0', '数码评测员', '具体是20号几点上架？', '-4'],
#  ['9054',
#   '150',
#   '2015/4/16',
#   '0',
#   'f***5',
#   '声道分离度60？？？你tmd在逗我吧，手机都90＋了，本来觉得外形不错可以考虑，却不公布dac和运放型号，公布会吓走爱好者？要么神逻辑要么渣芯片，这样只会吓更多烧油~',
#   '-4'],
#  ['9054',
#   '150',
#   '2015/4/16',
#   '1',
#   '三界商人',
#   '手机90？ 虚标了！    不过HiFi类产品的声道分离度至少是80左右，这明显是标错了的节奏啊 项目负责人摊上事儿了！哈哈',
#   '-4'],
#  ['9054', '151', '2015/4/16', '0', '强袭自由翻墙式', '求1元档中奖......', '-4'],
#  ['9054', '152', '2015/4/16', '0', '蘑***儿', '999档必须抢', '-4'],
#  ['9054', '154', '2015/4/16', '0', '万一的惊喜', '专业点啊  大哥~~~', '-4'],
#  ['9054', '155', '2015/4/16', '0', '1***7', '说一下支持的格式吧', '-4'],
#  ['9054',
#   '156',
#   '2015/4/16',
#   '0',
#   'kingfinnut',
#   '说下芯片和架构吧。这是最重要的居然没说。。。',
#   '-4'],
#  ['9054', '156', '2015/4/16', '1', '万一的惊喜', '[真棒]', '-4'],
#  ['9054', '157', '2015/4/16', '0', 'l***b', '这是二房？托的太没水准了。。。', '-4'],
#  ['9054',
#   '158',
#   '2015/4/15',
#   '0',
#   '男人三十多',
#   '我只想说，找托也要找点有水平的&hellip;&hellip;',
#   '-5'],
#  ['9054', '159', '2015/4/15', '0', '墨***思', '我想知道什么时候开始', '-5'],
#  ['9054',
#   '160',
#   '2015/4/16',
#   '0',
#   '粼***g',
#   '999太划算了！我加群问了，20号下周一开卖，具体时间还不告诉我，MD！早上我就蹲点999！一定要抢到！众亲们都去睡懒觉吧',
#   '-4'],
#  ['9054', '160', '2015/4/16', '1', '万一的惊喜', '专业点啊  大哥~~~', '-4'],
#  ['9054', '161', '2015/4/16', '0', '楚灵山', '什么时候上架？', '-4'],
#  ['9054',
#   '163',
#   '2015/4/16',
#   '0',
#   'y***e',
#   '太棒了!这么吊耳放只要999?什么时候开售?快说下呀!',
#   '-4'],
#  ['9054', '163', '2015/4/16', '0', '杀***汪', '这机器包含二房，但不能说它是二房[太阳]', '-4'],
#  ['9054', '163', '2015/4/16', '1', '万一的惊喜', '专业点啊  大哥~~~', '-4'],
#  ['9054', '164', '2015/4/16', '0', 'm***9', '看上去很专业的设备，很是期待！！！！', '-4'],
#  ['9087',
#   '275',
#   '2015/4/9',
#   '0',
#   'woodsroom',
#   '这个鼠标的尺寸是定制的吗？购买的时候要注明大中小尺寸吗？',
#   '-1'],
#  ['9087',
#   '276',
#   '2015/4/9',
#   '0',
#   '晓***0',
#   '都这价格了为何不配蓝牙？？现在都用蓝牙减少占用USB口而且方便；现在电脑都有蓝牙了！干嘛还这么落后！你配个蓝牙配个无线也行啊！建议！！',
#   '-1'],
#  ['9087',
#   '277',
#   '2015/4/9',
#   '0',
#   'jd_rock-2',
#   '三个手托的鼠标，俺第一次见，造型确实很高大尚，希望1元的能抽到我，谢谢！',
#   '-1'],
#  ['9087', '278', '2015/4/9', '0', '刘宇O', '国内还没看过这种鼠标，不错。什么时候开始？', '-1'],
#  ['9087',
#   '280',
#   '2015/4/9',
#   '0',
#   '烟***0',
#   '有配蓝牙吗，USB口不够用了，有线的就别众筹了，一点用处都没，出差都不方便携带',
#   '-1'],
#  ['9087',
#   '281',
#   '2015/4/9',
#   '0',
#   '晓***0',
#   '都这价格了为何不配蓝牙？？现在都用蓝牙减少占用USB口而且方便；再次，换新说是外观完整，请问磨损了不可以吗？？？',
#   '-1'],
#  ['9087', '282', '2015/4/9', '0', 'l***6', '何时开始众筹？', '-1'],
#  ['9110', '200', '2015/4/14', '0', 'l***y', '咋保修啊', '-1'],
#  ['9110', '201', '2015/4/14', '0', '139*****370_p', '嫩烤箱？听起来好新鲜', '-1'],
#  ['9110', '202', '2015/4/14', '0', 'l***y', '烤箱中的战斗机[真棒]', '-1'],
#  ['9110', '202', '2015/4/14', '1', 'l***y', '推广的不彻底啊，哪的圈圈好久不更新了吧。', '-1'],
#  ['9110', '204', '2015/4/14', '0', 'l***m', '光看造型就高大上，期待哦', '-1'],
#  ['9110',
#   '205',
#   '2015/4/14',
#   '0',
#   'jd_050147968',
#   '市面上烤箱的功能都具备吧？烘焙蛋糕什么的',
#   '-1'],
#  ['9110',
#   '205',
#   '2015/4/14',
#   '1',
#   '飘***筝',
#   '我们在镇上，你们说的在生活网下单如何配送？能覆盖到镇吗？',
#   '-1'],
#  ['9110', '206', '2015/4/14', '0', 'h***u', '不错呦，什么时候开始？', '-1'],
#  ['9110', '207', '2015/4/14', '0', '无尽的walt', '手工点个赞', '-1'],
#  ['9110', '208', '2015/4/14', '0', 'l***b', '当地没有本来生活网站覆盖怎么办，卡的有效期多久', '-1'],
#  ['9110', '208', '2015/4/14', '1', '飘***筝', '你看我们这里怎样，达州市麻柳镇能行不。', '-1'],
#  ['9110', '209', '2015/4/14', '1', 'jd_050147968', '同问，可否取代微波炉', '-1'],
#  ['9135',
#   '43',
#   '2015/4/11',
#   '1',
#   '笑***见',
#   '主要是想问这个酒的酒水和贵司其他品种里的哪种酒品相似？',
#   '-2'],
#  ['9135', '43', '2015/4/11', '1', '笑***见', '不是，我弄错了', '-2'],
#  ['9135',
#   '44',
#   '2015/4/10',
#   '0',
#   '想要翅膀的猫',
#   '感觉好奇怪啊，这不是随便弄瓶酒，然后自己整个心水的贴纸拍上去就是私人订制酒了？',
#   '-3'],
#  ['9135',
#   '45',
#   '2015/4/10',
#   '0',
#   '福***0',
#   '看着酒不错，可以参加下活动。每年至少获得3次免费品鉴酒机会，每次都能寄一瓶酒吗？',
#   '-3'],
#  ['9135', '45', '2015/4/10', '1', '刘宇0', '也有这个疑问', '-3'],
#  ['9135',
#   '46',
#   '2015/4/10',
#   '0',
#   '晓***0',
#   '什么时间开始众筹？ps.第一个支持你们的要不要给个惊喜之类的，众筹开门要红啊图吉利啊对不对[真棒]',
#   '-3'],
#  ['9137',
#   '29',
#   '2015/4/13',
#   '0',
#   'jd170女',
#   '以前总在欧美电视剧里看到过类似这样风格独特的儿童床、在这里看到还有点惊喜、总而言之：与众不同、值得期待！[玫瑰][真棒]',
#   '-1'],
#  ['9137', '30', '2015/4/12', '0', 'jd_wc碧', '校车那款，长宽高能说下吗', '-2'],
#  ['9137',
#   '30',
#   '2015/4/12',
#   '1',
#   '富***店',
#   '您好，感谢您对酷车儿童床的关注。校车床的外径尺寸为：2350（长）*1461（宽）*1655（高）MM。希望对您有帮助！',
#   '-2'],
#  ['9137',
#   '31',
#   '2015/4/12',
#   '0',
#   '富***店',
#   '送给孩子的一个健康环保的大玩具，圆宝贝一个汽车梦。让宝贝在小酷车的陪伴下健康快乐的成长，是我们共同的心愿！童年的时光很短暂，希望每个宝贝都能健康快乐的长大！来吧，还等什么呢？',
#   '-2'],
#  ['9137', '32', '2015/4/12', '0', 's***2', '这个床轮子是可以动的吗', '-2'],
#  ['9137',
#   '32',
#   '2015/4/12',
#   '1',
#   '富***店',
#   '您好，感谢您的关注。床的轮子不能随意转动，但可以拆卸，方便您节省空间靠墙摆放！',
#   '-2'],
#  ['9137',
#   '34',
#   '2015/4/10',
#   '0',
#   '医路-顺风',
#   '很可爱!四个轮子都能转吗？孩子能用到几岁?孩子长大了还能用吗?牢固性怎么样？孩子大了后不会压圬了吧?价格有点贵啊!',
#   '-4'],
#  ['9137',
#   '35',
#   '2015/4/10',
#   '0',
#   'jd_tiejin248',
#   '孩子非常喜欢那个红色的吉普车，四个轮子都能转吗？什么时候开始啊？',
#   '-4'],
#  ['9137', '36', '2015/4/10', '0', '我***芽', '2岁的宝贝用这个合适吗？这个真的没有异味吗？', '-4'],
#  ['9137',
#   '37',
#   '2015/4/10',
#   '0',
#   'jdyouban',
#   '这几个床真的很可爱，还真没见过这样的床，还有别的样子吗',
#   '-4'],
#  ['9137', '37', '2015/4/10', '1', 'jddonota', '无污染，有女孩款的就更有爱了[太阳]', '-4'],
#  ['9163', '137', '2015/5/27', '0', '米l虫', '第二代产品多久出来？', '-1'],
#  ['9163', '138', '2015/5/27', '0', '0***0', '十字钥匙能放几把', '-1'],
#  ['9163', '138', '2015/5/27', '1', '0***0', '这次众筹到手的是没有加长件的吗', '-1'],
#  ['9163',
#   '139',
#   '2015/5/27',
#   '0',
#   'z***3',
#   '支持本土化，对我来说只要好用就行。不过如果我的钥匙或者里面加的组件比较厚怎么办，那就只能放一点点东东了么？我想要把它的功能最大化啊。',
#   '-1'],
#  ['9163',
#   '140',
#   '2015/5/27',
#   '0',
#   'yinyuyangtj',
#   '好可爱的东东，感觉平时生活中会非常方便好用。产品大概重量是多少呢？',
#   '-1'],
#  ['9163', '141', '2015/5/27', '0', '泰***楚', '你好，请问39元档，万一没抢到，后期还会补吗？', '-1'],
#  ['9163',
#   '142',
#   '2015/5/27',
#   '0',
#   'l***2',
#   '不错，但感觉一套加长件不够用啊，怎么搞。可以另外配么',
#   '-1'],
#  ['9163', '143', '2015/5/27', '0', 'JT_PLAYER', '怎么还没开始，等不急了', '-1'],
#  ['9163', '145', '2015/5/27', '0', 'f***h', '彩色钥匙胚，为啥不单独出售，能适配多少钥匙？', '-1'],
#  ['9163', '146', '2015/5/27', '0', 'l***a', '货拿到手的时候装配不来怎么办，不要鄙视我[大哭]', '-1'],
#  ['9163',
#   '147',
#   '2015/5/27',
#   '0',
#   'd***8',
#   '这个一元档和后面若干实物产品档可以同时拍吗??一定要拍一元档才能参加apple watch抽奖，还是说产品档拍好了以后自动可以参加抽奖？？',
#   '-1'],
#  ['9163', '148', '2015/5/27', '0', 'l***2', '怎么还没上线，不是说的今天吗？？？', '-1'],
#  ['9163', '149', '2015/5/27', '0', 'f***h', 'keysmart山寨版', '-1'],
#  ['9163',
#   '150',
#   '2015/5/27',
#   '0',
#   'n***e',
#   'Hello ,Keysmart祖国版，你们能做到keysmart的品质吗？',
#   '-1'],
#  ['9163', '151', '2015/5/26', '0', 'heesa', '大钥匙可以用吗？房门的钥匙之类的？', '-2'],
#  ['9163',
#   '152',
#   '2015/5/26',
#   '0',
#   't***m',
#   '创意不错，但请问大家手上有几根钥匙还是长这样的？不过楼下说的不错，可以自己去配扁平。',
#   '-2'],
#  ['9163', '152', '2015/5/26', '1', 'kingfinnut', '创意是keysmart的好么。。。', '-2'],
#  ['9163',
#   '153',
#   '2015/5/26',
#   '0',
#   '缘霖',
#   '我觉得用这个产品，最好是将所用的所有带塑料头的钥匙全部去配成全金属扁平的那种，如果是A级锁钥匙估计配一把至少十元，B级锁钥匙得二三十元，C级的就难配了，而且钥匙装两头的话会无法藏在里面，视频中将一头钥匙换成U盘后另一头钥匙变没有办法藏进钥匙扣内，而且视频中的钥匙都是些小的钥匙。',
#   '-2'],
#  ['9163', '154', '2015/5/26', '0', 's***4', '看上去很不错的样子 支持支持[可爱]', '-2'],
#  ['9163', '155', '2015/5/26', '0', 'kingfinnut', 'keysmart的祖国版终于来了', '-2'],
#  ['9163', '156', '2015/5/25', '0', '米l虫', '能装的钥匙少了点，能不能几个KeyBank组装到一起？', '-3'],
#  ['9163', '157', '2015/5/25', '0', '风声雨声跳票声', '39的里面有几把钥匙', '-3'],
#  ['9163', '158', '2015/5/25', '0', 'DavidandLi', '你的钥匙挺好看的！', '-3'],
#  ['9163', '159', '2015/5/25', '0', 'iStation', '感觉不能挂在裤腰间容易乱丢了。', '-3'],
#  ['9163',
#   '160',
#   '2015/5/25',
#   '0',
#   'l***2',
#   '看着不错，什么时候上线。还有钥匙胚什么的是要我自己去配么到时候？',
#   '-3'],
#  ['9163',
#   '161',
#   '2015/5/25',
#   '0',
#   'w28317881',
#   '车钥匙能放进么？还有&middot;我们家门是十字锁的钥匙&middot;这个能放几把进去？请告知&middot;',
#   '-3'],
#  ['9163',
#   '162',
#   '2015/5/25',
#   '0',
#   'Leoit',
#   '请问39元档的能把普通U盘放进去吗？另外材质会脱色吗？',
#   '-3'],
#  ['9163',
#   '163',
#   '2015/5/25',
#   '0',
#   'jd_6777921cb4209',
#   '没想到预热的地方就这么热闹，哈哈，这年头能引起话题的产品就是值得关注的好产品！京东众筹在业内是响当当的严格和专业，能够在这里上线的一定是优秀创新的东东。我有两个问题想问下，一个是请解释下适配什么类型和多少数量的钥匙？还有一个是对朝九晚五的城市人来说一般推荐加入什么组件？',
#   '-3'],
#  ['9163',
#   '164',
#   '2015/5/25',
#   '0',
#   'l***a',
#   '各位对一个新项目要求也稍微苛刻了点吧。我没想那么多，我觉得吧，东西好看，实用，最重要是价格合理就是值得支持的，仔细看看本来就是39 49的档位，而且看上去做工啊颜值啊都还不错，给自己的回报适当产品也过硬就OK了。买东西最重要是注重性价比，好的东西更切合国内的实际和价位有什么不好',
#   '-3'],
#  ['9163', '165', '2015/5/25', '0', 'jove0916', '不实用', '-3'],
#  ['9163',
#   '166',
#   '2015/5/25',
#   '0',
#   'zhangwendao',
#   '建议侧面增加一个类似刀上的背夹，来保证它的安全，夏天不易遗失。',
#   '-3'],
#  ['9163',
#   '167',
#   '2015/5/25',
#   '0',
#   'jd_feiy012',
#   '没看出来哪里智能，还以为带蓝牙报警防丢失之类的功能呢，有违智能二字了。',
#   '-3'],
#  ['9163',
#   '168',
#   '2015/5/26',
#   '0',
#   '缘霖',
#   '这个东西想法很好但我觉得并不实用，我们现在经常用的钥匙一般外观都比较厚实，类似480锁，双保险锁的钥匙很少有人用，要么就是抽屉更衣柜，也是很少使用的钥匙。家里若还用这种80锁，双保险锁，那家庭条件也是很寒酸了。',
#   '-2'],
#  ['9163',
#   '168',
#   '2015/5/26',
#   '1',
#   '缘霖',
#   '我所有薄的钥匙都是单位的，家里的两把钥匙就厚达1.5厘米，家里的钥匙装上去使用上应该会不方便，比如转动困难，转出来了又很松，装进去时又比较紧，松垮了就和钥匙圈没区别了。这个产品只适合老式的钥匙。',
#   '-2'],
#  ['9163',
#   '168',
#   '2015/5/25',
#   '1',
#   '五彩鸟',
#   '我12把钥匙， 每把大小 形状 长短都不一样，用钥匙包方便多了',
#   '-3'],
#  ['9163',
#   '168',
#   '2015/5/26',
#   '1',
#   '五彩鸟',
#   '同意 没用处 视频里那男人找钥匙开门换了好几个钥匙，难道用你这个就一次能找了啊',
#   '-2'],
#  ['9163', '169', '2015/5/25', '0', '快乐随身带', '这个也叫智能，真没有看到有那里智能的。。。', '-3'],
#  ['9163',
#   '170',
#   '2015/5/25',
#   '0',
#   'z***3',
#   '装配的时候用什么工具呢？会不会很复杂？都要自己DIY？我就很喜欢自己动手做，有点宜家的赶脚，那加U盘啊数据线啊都可以随自己需要了，每次人家问我借个U盘都不还给我，这下借给人家一整个总不好意思不还我了吧，妈妈再也不用担心我老是掉U盘了。。。',
#   '-3'],
#  ['9163', '171', '2015/5/25', '0', 'r***6', '什么时候开卖', '-3'],
#  ['9163',
#   '172',
#   '2015/5/25',
#   '0',
#   'l***2',
#   '感觉还行，虽然看到过类似的产品，但是这个回报价格还是十分厚道的，支持一个~',
#   '-3'],
#  ['9163',
#   '173',
#   '2015/5/25',
#   '0',
#   'o***o',
#   '赤果果的山寨吗？国外什么keysmart、keybar早就卖了好几年了，关键是这东西跟keysmart长得几乎一模一样啊，连那个小的钥匙圈也几乎一模一样啊，不过价格倒是比国外那些便宜不少，但是keysmart官网提供定制，发钥匙照片，加钱他们就定做一个完美匹配的钥匙啊&middot;&middot;&middot;',
#   '-3'],
#  ['9163',
#   '173',
#   '2015/5/25',
#   '1',
#   'o***o',
#   '好吧，鉴于价格比国外的低，就支持一下吧，不过希望以后的产品把外形改一下吧，至少不能跟国外的一模一样吧&middot;&middot;&middot;&middot;',
#   '-3'],
#  ['9163',
#   '174',
#   '2015/5/25',
#   '0',
#   'd***8',
#   '钥匙还可以这么好看哇，有没有粉粉色的少女风啊？弄一个放在包包里肯定很炫呀，可以都收纳起来的话拿进拿出包包就不会刮坏了吧。。。支持！',
#   '-3'],
#  ['9163',
#   '175',
#   '2015/5/25',
#   '0',
#   'JT_PLAYER',
#   '挺好的，杂乱的钥匙终于有了它们的归属。再也不用担心钥匙划伤手机屏幕的问题了，赞。',
#   '-3'],
#  ['9163',
#   '176',
#   '2015/5/25',
#   '0',
#   '孫BoBo',
#   '这不是活生生的抄袭吗&hellip;&hellip;',
#   '-3'],
#  ['9163',
#   '176',
#   '2015/5/25',
#   '1',
#   'a***1',
#   '哥们说的是keysmart，真心不错，但真心太贵。这个的价格还是比较能接受的。',
#   '-3'],
#  ['9163',
#   '177',
#   '2015/5/25',
#   '0',
#   '湘_遇',
#   '这种也叫智能？我笑了，你们呢？现在的商家，怎么这么会用词，相机800W就是超高像素，U盘8G就是超大内存，这种也居然叫只能，你们帮我科普一下，到底智能在哪里，什么才叫智能，我真心没看懂智能在哪里？',
#   '-3'],
#  ['9163',
#   '178',
#   '2015/5/25',
#   '0',
#   '蓝色de羽翼',
#   '不怎么看好，现在钥匙种类太多了，十字钥匙圆孔钥匙，防盗门钥匙呢，根本没法搞',
#   '-3'],
#  ['9163', '179', '2015/5/25', '0', 'a***1', '使用加长组件后，最多可以放多少把钥匙？', '-3'],
#  ['9188',
#   '73',
#   '2015/4/12',
#   '0',
#   'cityhunterxyzvbw',
#   '额，又是个云产品。这个使用按摩椅的人不能自己控制么？难道别人比他自己更了解他的需要？何必弄个云控制？意义何在？至于所谓的新添加自动程序，完全可以通过网络图文的形式教给使用者。我觉得能用的了云产品的人不至于连上网看点资料都做不到吧。',
#   '-1'],
#  ['9188', '74', '2015/4/11', '0', 'doooot', '这应该是很大的公司了吧', '-2'],
#  ['9188',
#   '75',
#   '2015/4/11',
#   '0',
#   '鳗***吧',
#   '金额就设定5W，商家对此产品没信心？？一台就1W了&hellip;&hellip;',
#   '-2'],
#  ['9188',
#   '76',
#   '2015/4/11',
#   '0',
#   '沭***泪',
#   '呦，搞得跟婴儿床似的，肯定很舒服是吧，不过价格太贵啦！',
#   '-2'],
#  ['9188', '77', '2015/4/10', '0', 'wangxp2011', '太贵了。离谱了。这不是新硬件的搞法。', '-3'],
#  ['9188', '78', '2015/4/10', '0', 'h***9', '还有具体什么时候开始', '-3'],
#  ['9195',
#   '73',
#   '2015/4/13',
#   '0',
#   '晓***0',
#   '什么时间开始众筹？ps.第一个支持你们的要不要给个惊喜之类的，众筹开门要红啊图吉利啊对不对',
#   '-2'],
#  ['9196', '278', '2015/4/20', '0', '187*****396_p', '能搭配ios吗', '-1'],
#  ['9196', '279', '2015/4/20', '0', '187*****396_p', '防水吗', '-1'],
#  ['9196',
#   '280',
#   '2015/4/20',
#   '0',
#   'jd_窃国怪盗',
#   '近视怎么办？是否考虑过佩戴光学镜片后，屏幕成像的问题。',
#   '-1'],
#  ['9196',
#   '281',
#   '2015/4/19',
#   '1',
#   'wxy9996',
#   '我来玩的 我错了吗 一人一B 下面两个就是2B。。。。。。。。。。。',
#   '-2'],
#  ['9196', '281', '2015/4/18', '1', 'H***3', '你傻啊？', '-3'],
#  ['9196',
#   '283',
#   '2015/4/19',
#   '0',
#   '盗版商人',
#   '我想问一个比较傻的问题，大家别笑我[难过]如果在使用的时候，能不能把眼镜镜片部分摘掉，只有留眼镜框和摄像头的部分，这样还能正常使用吗？',
#   '-2'],
#  ['9196', '283', '2015/4/19', '1', 'l***i', '可以的', '-2'],
#  ['9196',
#   '284',
#   '2015/4/18',
#   '0',
#   '飞花残阳',
#   '这1999 性价比不高 卖点估计也就那虚无缥缈的免费换二代吧  这种东西也就是个阉割的安卓手机 除了耍酷装逼外没多大用处 玩几天新鲜感过了也就成抽屉里的一员了 价格在1500内 或许才会大卖',
#   '-3'],
#  ['9196',
#   '284',
#   '2015/4/18',
#   '1',
#   'jd_445785441',
#   '能耍酷装逼说明有妹纸搭讪啊，1999亏么？',
#   '-3'],
#  ['9196',
#   '285',
#   '2015/4/17',
#   '0',
#   'cityhunterxyzvbw',
#   '东西不错，价格太高。顺便提醒各位土豪一声，戴的时候小心了，这玩意估计不禁摔。路过赞一个。',
#   '-4'],
#  ['9196', '286', '2015/4/17', '0', '飞花残阳', '是带安卓系统的吗？ 要是没系统的  就无爱了', '-4'],
#  ['9196',
#   '287',
#   '2015/4/17',
#   '0',
#   '普通百姓小铭',
#   '瞪大眼睛看清楚不是google眼镜哦！还以为是google眼镜，心动了一下！晕倒了！GLXSS智能眼镜应该是拍摄眼镜吧和用智能太浮夸了吧！！',
#   '-4'],
#  ['9196', '289', '2015/4/17', '0', '在路上的风1', '这照片质量看着还不错的样子，确实是眼镜拍的吗？', '-4'],
#  ...]

# %%
np.asarray(contents) #convert list to numpy array
# Out:
# array([list(['项目id', '第几条主评论', '日期', '是否是回复', '评论者id', '评论文本', '众筹前第几天']),
#        list(['3510', '152', '2015/5/6', '0', 'gaodapk', '一开始我以为是你们帮设计表白图案那，我想买一件那种把自己设计的图案画到衣服上，就是用丙烯画那种。我有自己初步草图不知UI设计师能否帮完善 再画到衣服上哪？', '-1']),
#        list(['3510', '154', '2015/5/6', '0', '158O1319OO6', '我感觉就是UI设计师在拼颜值啊~谁看好他就支持他，颜值高支持多，我有点想支持了。。。', '-1']),
#        ...,
#        list(['60781', '457', '2016/6/22', '0', 'j***g', '啊啊啊啊！从微博上看到就果断来搜了！前排啊！！这时候拼的就是手速了！', '-3']),
#        list(['60781', '458', '2016/6/22', '0', 'jd_GOODLI624', '我抢，求抽中[太阳][握手]', '-3']),
#        list([''])], dtype=object)

# %% [markdown]
# ## Put data into dataframe

# %%
#convert numpy array to pandas dataframe 
xiahua = pd.DataFrame(data=contents[1:], columns = contents[0])

# %%
#renamed columns to English
#I could also have renamed the columns when I first instatiated the dataframe
#There's more than one way to get to the same solution
xiahua.rename(columns={'项目id':'Project ID'
                         , '第几条主评论':'Discussion ID'
                         , '日期':'Date', '是否是回复':'Reply'
                         , '评论者id':'Discussant ID'
                         , '评论文本':'Text'
                         , '众筹前第几天':'Days Before'}, inplace=True)

# %%
xiahua.drop([46441], inplace=True) #dropped empty row

# %%
xiahua.head()
# Out:
#   Project ID Discussion ID       Date Reply Discussant ID  \
# 0       3510           152   2015/5/6     0       gaodapk
# 1       3510           154   2015/5/6     0   158O1319OO6
# 2       3510           156   2015/5/5     0        逆战游戏玩家
# 3       3722           106  2015/4/27     0      jove0916
# 4       3722           108  2015/4/27     0       有Bigger
#
#                                                 Text Days Before
# 0  一开始我以为是你们帮设计表白图案那，我想买一件那种把自己设计的图案画到衣服上，就是用丙烯画那...          -1
# 1         我感觉就是UI设计师在拼颜值啊~谁看好他就支持他，颜值高支持多，我有点想支持了。。。          -1
# 2                                         什么时候开卖[疑问]          -2
# 3                                              几点开始啊          -1
# 4                                         具体什么时间开始呢？          -1

# %% [markdown]
# # Basic text pre-processing
# ### Remove punctuation

# %%
xiahua['Text'] = xiahua['Text'].str.replace('[^\w\s]','') #removes punctuation

# %% [markdown]
# ### Remove English characters

# %%
#make all English characters lower case. We do this because Python is case sensitive 
xiahua['Text'] = xiahua['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
cleaned = []
for text in xiahua['Text'].iteritems():
    cleaned.append(re.sub('[a-z]', '', text[1]))

# %%
xiahua['Text'] = cleaned

# %% [markdown]
# ### Remove numbers

# %%
cleaned = []
for text in xiahua['Text'].iteritems():
    cleaned.append(re.sub('[0-9]', '', text[1]))

# %%
xiahua['Text'] = cleaned

# %% [markdown]
# ### Remove Chinese stop words

# %%
#read in chinese stop words into a list
stop_chinese = []
with open('stopwords.txt', encoding='utf8') as f:
    for line in f:
        line = line.strip() 
        stop_chinese.append(line) 
    f.close()

# %%
test = xiahua.copy()

# %%
somewords = ['多次下单哈哈', '吼吼吼给很多人看了都说不错快点到号吧要下手啦 哈哈哈哈哈']

# %%
seg_list = jieba.cut('多次下单哈哈', cut_all=False)
# print("Full mode: "+"/ ".join(seg_list))

# %%
def remove_chinese_stop_words(text_column, stopwords):
    new_col=[]
    for text in text_column.iteritems():
        seg_list = jieba.cut_for_search(text[1])
        final_str = ""
        for seg in seg_list:
            if seg not in stopwords:
                final_str = final_str+seg
        new_col.append(final_str)
    return new_col

# %%
new_col = remove_chinese_stop_words(test.Text, stop_chinese)

# %%
test['Cleaned_Text'] = new_col

# %%
test.loc[test.Cleaned_Text.str.contains('者')]
# Out:
#       Project ID Discussion ID        Date Reply         Discussant ID  \
# 48          5339            97   2015/4/19     0              cnhkygmm
# 162         5565           110   2015/4/13     1                sootao
# 367         7502            32   2015/4/10     1                jd_风儿伤
# 375         7598           104   2015/4/22     0                    以马
# 495         8019           249   2015/4/20     0                 7***m
# 507         8019           262   2015/4/18     0         jd_╰Esc__·╮坚强
# 876         9054           150   2015/4/16     0                 f***5
# 979         9188            73   2015/4/12     0      cityhunterxyzvbw
# 1006        9196           296   2015/4/17     0                  六月之雨
# 1062        9214           140   2015/4/16     1                 网***6
# 1224        9316            29   2015/4/14     0                   湘_遇
# 1234        9469            84   2015/4/18     0               wxy9996
# 1493        9703           328   2015/4/21     1                艾芯baby
# 1559        9703           385   2015/4/18     0               wxy9996
# 1617        9854           192   2015/4/18     0               wxy9996
# 1860        9854           425   2015/4/16     0                 z***l
# 1912        9869           265   2015/4/18     0               wxy9996
# 1938        9871           637   2015/4/19     0               wxy9996
# 2089        9883           469   2015/4/17     0                 w***n
# 2104        9883           475   2015/4/17     1                 w***n
# 2140        9927            27   2015/4/19     0               wxy9996
# 2484       10268           690   2015/4/22     0               半夏微凉ooo
# 2566       10304          1274   2015/4/25     1                 D***1
# 2657       10411            67   2015/4/25     0                  山东书生
# 2666       10411            72   2015/4/24     1                  山东书生
# 3399       11057           143   2015/5/20     0                 jd_路基
# 3401       11057           144   2015/5/19     0                 jd_路基
# 3968       11375           240    2015/5/6     0                    紫赟
# 4009       11375           258    2015/5/5     0               实智官方旗舰店
# 4042       11386           620   2015/5/11     0                 稻***0
# 4099       11386           662    2015/5/8     0              缝纫工68746
# 4143       11386           700    2015/5/9     1                 在***吧
# 4156       11389            76    2015/6/7     0                 饥饿的琼斯
# 4650       12101           293   2015/5/13     0                 m***j
# 4766       12266           578   2015/5/18     0                 l***a
# 4891       12266           663   2015/5/15     0                 x***贝
# 5307       12619            50   2015/5/21     0                 温***调
# 5678       12711          2050   2015/5/24     1                 快乐随身带
# 6002       13273           185   2015/5/27     0              xingao49
# 6062       13291           464    2015/6/4     1                 楽_可_可
# 6143       13351           420   2015/5/27     0                  中科奇点
# 43669      54517           184   2016/5/10     1                 c***y
# 43750      54673           692    2016/5/8     1                 砖投旗舰店
# 44298      56164            88   2016/5/22     1          jd_186636wsy
# 44345      56164           111   2016/5/22     1          jd_137916sqw
# 44367      56164           120   2016/5/21     1          jd_186636wsy
# 44478      56261            48   2016/5/21     1         优派科技ViewSonic
# 44888      57246           114    2016/6/4     0           jdxiaoaoatj
# 46079      58008           266   2016/6/14     0          mglxsnxmbiux
# 46106      58228           202    2016/6/6     1                 大***3
# 46284      60781           330   2016/6/24     0           jd130841nvo
# 46328      60781           366   2016/6/23     0            jd_2154668
# 46335      60781           372   2016/6/23     0            jd_4540489
# 46340      60781           377   2016/6/23     0                 liu刘鹏
# 46396      60781           419   2016/6/22     0                 j***f
# 46412      60781           434   2016/6/22     0                 叶***6
# 46427      60781           448   2016/6/22     0                 j***2
#
#                                                     Text Days Before  \
# 48     电脑可以直接访问云盘无需安装软件这点很赞但不清楚是否可以在电脑上操作将电脑云盘手机三者之间的...          -4
# 162                                  欢迎加群  众多电子烟爱好者的聚集地哦          -2
# 367    亲其实任何品牌的车主都有参加选择支持或反对此次保养众筹的权利虽然品牌不同但是认真选择正确判断...          -4
# 375    靠手杆抛杆都能承受吗能承受我是不是还要单独线要几点零的线更安全些你这东西标价多配备为什么不全...          -5
# 495                                       希望不要让消费者们失望了握手          -3
# 507                                   支持者每人发一台体验一下那就好了嘿嘿          -5
# 876    声道分离度你在逗我吧手机都了本来觉得外形不错可以考虑却不公布和运放型号公布会吓走爱好者要么神...          -4
# 979    额又是个云产品这个使用按摩椅的人不能自己控制么难道别人比他自己更了解他的需要何必弄个云控制意...          -1
# 1006   而最后也是最严重的不足则是太少了感觉产品上市的太早了硬件设计上虽然已经完成但是还远远没有跟上...          -4
# 1062   您好感谢您对酷多啦儿童智能手表的支持在元的支持者中将由京东官方抽取位幸运支持者每人送出酷多啦...          -1
# 1224                     支持安卓系统吗好像没看见页面介绍呢或者说只要带蓝牙的手机都可以          -1
# 1234   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -2
# 1493   能否实时监控使用者 心率 心电状况 比如长期心率不齐早搏 或间隙性心率不齐患者 的全天心脏搏...          -1
# 1559   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -4
# 1617   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -2
# 1860                            有谁愿意组个人团吗每人能便宜大洋呢有意者商量商量          -4
# 1912   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -3
# 1938   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -1
# 2089      我们的产品努力在技术与体验中找到平衡让一切真正回归到产品本身在技术使用美感等各个方面真...          -4
# 2104   您好感谢您对  的支持这款螺丝刀是手自一体的设计电动扭矩是手自一体的设计更加保护使用者和适用...          -4
# 2140   凡是一元档每多少位支持者中抽取个幸运者什么的 建议大家都不要去支持一元档了 最好就个支持者 ...          -1
# 2484            设计太暖心了期待萌萌妹目测外型好喜饭都别跟我抢我要成为第一批使用者真棒耶耶耶再见          -2
# 2566   京东众筹和京东商城都是通用京东账号系统这个是京东商城和京东金融的规则定义我们也是规则的参与者...          -3
# 2657   普洱茶树包括古树茶大树茶小树茶台地茶估计年树龄的古树茶都被保护起来了现在有些不良商家用混淆的...          -2
# 2666   普洱茶树包括古树茶大树茶小树茶台地茶估计年树龄的古树茶都被保护起来了现在有些不良商家用混淆的...          -3
# 3399         设计委新颖骑行者们都感谢你能说明一下灯珠的型号吗或者能更换更高型号的灯珠吗厦门天骑车队          -1
# 3401                                     太低了设计者应该没有夜骑的经历          -2
# 3968   插排上电视机关机后分钟后只会断开电视机以及其联动的两个设备如机顶盒音响的电而口以及两个常通插...          -6
# 4009                                   我靠对于我这种强迫症患者绝壁是福音          -7
# 4042             我是篮球爱好者我想买回去练练腰腹力量这可是滞空时间的关键希望可以让自己飞多一会          -2
# 4099   看了楼下的说道了微创新这个店我也挺有感触现在很多成功的企业都是靠微创新成家的比如本身就有很多...          -5
# 4143   我说那个卖信用卡的哥别人家的东西看起来好歹也挺实用的好不好我还真找不到这种专做仰卧起坐运动的...          -4
# 4156   希望能和一样内置及电流计且引出视频输入输出及引脚这样才方便元以下支持者安装图传否则后期安装及其不便          -1
# 4650                经历充电器起火后这个会不会有类似问题相信大部分消费者比较注重这个问题大哭          -1
# 4766                屏幕可大大提升屏幕画面的质感和机身整体的视觉效果让使用者手握持感更为舒适          -1
# 4891                        好高大上的手机啊期待中还有元免单机会希望我会是那个幸运者          -4
# 5307                                    位支持者看来群众的眼睛都是雪亮的          -6
# 5678   京东官方抽奖平台从名支持者里抽取多名幸运用户多名是多少名吗是的话算我一元哈哈_大 城 小 爱...         -10
# 6002   应该明确标明附有后技支持以上我们会附带端蓝牙适配器完美对接小易亦可与其他蓝牙设备对接小时前这...          -5
# 6062   那个什么我也是醉了花十几万买的车子年后都得报废难道想期望花几百块买的锅能用一辈子疑问还当传家...          -1
# 6143   世界上有很多行为背后的目的并非是常人所想象那样因为所处的层面不同比如说为了维护某一个大坝可能...          -6
# 6150   关门就会锁闭如果外面的指纹是系统认证的当然可以打开当然门的内部还可以进行二重反锁这样外面就打...          -6
# 6183                                              创业者不容易          -7
# 6218                           好便宜抢抢试试不过差价这么悬殊貌似消费者不会买账吧          -6
# 6400   ９９９是成本价害羞还送礼 这款产品代表了目前已知智能硬件里面的最高技术含量这款产品里面有８０...          -1
# 6585   看着超酷是不是和似的真实具体这些有什么游戏高科技玩意啊可以兼容哪些游戏有多少款游戏可以玩游戏...          -4
# 6617                                           为什么还是开发者版          -5
# 6768                南宁是全国最大的电动车市场不能上牌我怎么敢买这都做不到还玩众筹欺骗消费者          -1
# 6772                南宁是全国最大的电动车市场不能上牌我怎么敢买这都做不到还玩众筹欺骗消费者          -1
# 6836   尾箱不仅是收纳空间的问题还有利于提高安全性因为电动车自身体积小增加尾箱可以增加整车侧向和后方...          -1
# 6847   小牛管家功能可以定位可以导航在新城市工作必备出门不怕抓瞎了防盗功能很给力停在街上可以稍微省点...          -1
# 6909   擦越来越不靠谱都市就不能有限量就一定是平民版好歹你有个选择给群众们所有帖子有是毛水军你花点心...          -3
# 6922   不要怪我太坦白整个就一小米第二嘛什么人体工程学环保啥的全扯淡就是针对年轻人的新奇心理拿人家的...          -3
# 7005   简约 优雅的设计就和苹果一样对设计精益求精对很多的功能介绍也很贴心能对使用者对产品有一顶的黏...          -4
# 7075   买早了刚买了一辆的绿源没法退支持这个项目不贵博世和松下几个品牌背书的配件就值钱的很核心问题是...          -4
# 7092   基本功能要齐全后备箱安全骑行与安全存放等增设互联网的新功能如充电遥控开关锁凳不要给无关的赠品...          -5
# 7194                  设计者没考虑在一二线城市上不了拍照吗而且县级市多数人都骑摩托车悲催啊          -6
# 7289                      有保险吗公司如果买个集体保险什么的 作为爱好者比较担心制动噢          -7
# 7437   有些话要说前后碟刹 是不是太猛了 的铃木超人 都是前碟后鼓 你这么小的车碟刹 不怕打滑摔死吗...          -8
# 7538   买电动车消费者第一眼看外观第二看价格外观方面后部好看前面的挡板及大灯感觉不太拉风前挡板与踏板...          -9
# 7686   电动车上牌问题是否解决 电池防盗问题可否解决 相应配件开发上市速度如手机导航支架靠背等 电池...         -11
# 7687   看起来整体还行踏板部分是不是设计得太厚了有点难看而且提高了整个坐姿我知道那个里面是锂电池但是...         -11
# 7774   每个人后面都是一个群体我的建议仅仅是代表我们这个群体的建议工业时代产品可以定制人人都是设计师...         -11
# 7968   挺好但是太贵用华为降成本的传统美德吧拜托便宜一点吧数量上去了再压榨供应商成本利润空间从厂家来...         -12
# 8072   感觉众筹还可以价格给点优惠支持者毕竟一个新星品牌且线下售后严重不普及的情况下支持必是忠诚粉白...         -13
# 8154   作为一个成熟的电动车爱好者其实我不追求车速安全性考虑很少载人路上交警太多我更关注的是整车前后...         -13
# 8174   松下电池一节就算元单就电池个元元了加上市场上绝大部分锂电车厂家不直接生产锂电池无法做到锂电池...         -13
# 8475                         这个法规早已经跟不上时代需求或者说执法还远远跟不上法规         -13
# 8553   守护者木头烟斗和雾化器售后怎么个保修保换雾化器一般不用换呗 雾化芯一般多长时间一换 烟油一瓶...          -3
# 8866    您好我们是众筹结束后的天内陆续发货的为满足广大消费者我们需要时间进行严格的生产检测的感谢您的关注          -1
# 8883   好的开始在互联网时代电子烟的生产研发企业也尝试用新的方式来销售并且也开始关注国内品牌的建立玫...          -1
# 8971   刷头价格大概是多少需要考虑后续成本另外建议采用充电型设计消费者是愿意为更便捷的商品买大单的另...          -3
# 9085                  好坏都是因人而异的应该带着宽慰的心态去看待每一个项目都是开发者的心血          -2
# 9094   这个设计的踏脚和健身房的单车很相似怎么没人去喷怎么没有人拿它来谈什么几何谈什么姿势因为它是成...          -2
# 9095   任何东西都有它被喷的一面人无完人世界没有什么东西是十全十美的我认为商家应该多听听负面建议的是...          -2
# 9117   大家关注你才过来评论难道希望一个人都没有才最好吗看到产生疑惑的人商家应该想的是怎么让消费者打...          -3
# 9239                                  爷爷也曾是糖尿病患者期待试用这个产品          -2
# 9244                               关注很久了舅妈和四姥姥是糖尿病患者期待拥抱          -2
# 9577                                         或者说送我一个更好哈哈          -4
# 9608                                    去淘 宝上看看  使用者的感受吧          -5
# 9820                                          太贵欺骗消费者呢是不          -4
# 9896            京东官方将从名支持者中抽取名幸运用户以元专属价获得的电动滑板车一辆你可以这么幸运          -1
# 11496  亲你都讲到我的心坎里去了索爱是国家高新技术企业在数码时代跟魅族爱国者被誉为四大金砖曾在央视湖...          -3
# 11519     众筹还是很好的让我们消费者得实惠又不担心买了有问题的话不退我喜欢不满意直接退这句话为众筹点赞          -3
# 11524  刚仔细看了下页面上的内容希望能给真正有需求的人建议首先从配置上来分析这款机有如下优点摄像头的...          -3
# 11525  万的角度来说应该不低的运行内存尽管不是最高但还算主流相对于一般的游戏也到能轻松应对我们都知道...          -3
# 11527  以及全合金机身结合图片应该在材质和氧化及工艺上下了不少功夫就这外观确实是目前大几千元机器上才...          -3
# 11529  当然这还得取决于方案但商家又强调忘记参数体验才是王道来说又很自信虽然有疑惑但还真有期待了品质...          -3
# 11534  当然这还得取决于方案但商家又强调忘记参数体验才是王道来说又很自信虽然有疑惑但还真有期待了品质...          -4
# 11536  以及全合金机身结合图片应该在材质和氧化及工艺上下了不少功夫就这外观确实是目前大几千元机器上才...          -4
# 11538  刚仔细看了下页面上的内容希望能给真正有需求的人建议首先从配置上来分析这款机有如下优点摄像头的...          -4
# 11568  哎你们搞点创新好不好呢这个东西众筹审核如果通过真的无语了这个东西就好比我们人急了需要放屁跑到...          -1
# 11644  既然是电视机怎么会无屏这悬念搞的其实个人最讨厌捆绑智能系统了硬件不能升级上半年出四代下半年就...          -4
# 11930                           还真是一次前无古人后无来者的强大直接把我给吸引了          -1
# 12098                           最关键也是消费者最关心的一个数据行驶里程没有说明          -3
# 12255                                        不是小号这个号是发起者          -1
# 12451  这个没有可比性速最大传动比就是说用脚蹬一周后轮要转圈这车的传动比也就是说脚蹬一周后轮要转圈前...         -13
# 12489                                        麻烦发起者回答一下谢谢          -1
# 12491  还没开始筹款吗不是说倒计时了吗谢谢大家的关心和京东的众筹团队商议后决定以更优惠的价格回报支持...          -1
# 12532                                              脸萌开发者          -7
# 13103  不是的因为彩色只是在娱乐的时候会用到大部份日常使用都是照明用途做白光灯是想消费者的成本更低些...          -5
# 13153                                       哎呦如此大方来者不拒真棒          -2
# 13198                  进入锁定状态的车子会自动检测使用者身份符合会自动解除警报否则会报警          -8
# 13470            一个仿手柄的东西真心觉得设计者是不是就没想过要制作出一个真正的有新意的东西疑问          -2
# 13565  想买一个不过还是对链条工作时的声音没有直观的认识可以发布一个车子工作时带声音的视频吗或者说有...          -8
# 13845                  贵公司产品和嘟嘟车心很像啊能否说一下你们好在哪里啊选择困难症患者致          -6
# 14052                       那以后这张卡可以像普通上网卡或者说手机那样更换流量套餐吗         -10
# 14182  我自己接了条线到网关我装的杂牌导航都能控制你们应该是没问题的现在反应这么好赶紧出哦别想锤子刚...         -11
# 14211  消费者永远是弱势群体大多时候为了点小钱也没时间没精力去维权而商家则是很多时候售前售后两个样夸...          -2
# 14273  诚然企业上次做的不够好但是我们一直都做到了业内较长的天无条件退货随时质保维修同时上次众筹我们...          -3
# 14321  诚然企业上次做的不够好但是我们一直都做到了业内较长的天无条件退货随时质保维修同时上次众筹我们...          -4
# 14328                                           清者自清浊者自浊          -4
# 14331                                  为了不让更多人上当 维护消费者权益          -4
       如果抽到幸运者会是我就太感谢了后期我会一直关注和推荐的的          -1
# 33862                             出厂预装的系统是什么或者说能否备注预装的系统          -1
# 33987                感觉设计师很用心的在为我们消费者考虑问题这个设计非常棒买单什么时候开始          -4
# 34064  我虽然不是什么发烧友但也知道车架数值对骑行者的重要性每款介绍只标注了型号细分也只有三个型号请...          -1
# 34166                                      铅酸电池价把消费者当病猫了          -3
# 34672  上一期复仇者系列就挺看好的不过微信分享活动杳无音讯是啥情况呢活动截止早已过了中奖名单都私了么 难过          -1
# 34921  请问这个产品后续在国内会招商吗我们是做净水器的商家我们想代理这个品牌目前国内较缺类似产品消费...          -2
# 35034  呵呵看来那垃圾纵影伪还真坑了不少人啊本人也是受害者之一在此友情提醒大家京东众筹的项目鱼龙混杂...          -2
# 35042   楼主看您的大名应该是卖手机和配件的难道泱泱大国就您一家可以卖手机和配件吗或者说就您一家有价格优势          -1
# 35383                                是京东官方从元支持者中每名中抽取名的哦          -2
# 35514                                     产品的设计者是男的还是女的啊          -1
# 35695                                    使我们低收入者的福音呀功德一件          -1
# 35701                                      这价格还算对得起我们消费者          -1
# 35814                                         怎么知道自己是幸运者          -1
# 35866                       如果抽到幸运者会是我就太感谢了后期我会一直关注和推荐的的          -1
# 35921                                    使我们低收入者的福音呀功德一件          -1
# 35925                                      这价格还算对得起我们消费者          -2
# 36430                                    科鲁兹飞哥导航开拓者能用亿连不          -5
# 36432                                    科鲁兹飞哥导航开拓者能用亿连不          -5
# 36762               升级电池模块是左右两边都有预留还是只有一边或者说一边是标配电池另一边预留          -4
# 36892  嘿嘿我们产品独一无二的从最初设计到最后量产几乎把每个环节都考虑到了为了就是给消费者尤其是一些...          -6
# 37248  嘿嘿嘿我们是专门针对商务人士包括男性和女性尤其是奋斗在一线的创业者们无论何时 都可以用我们的...          -5
# 37344  请问元档的豪华套餐可以实现当门磁报警的同时摄像头同步智能摄录并通知到使用者然后打开就能看到当...          -1
# 37419    科技产品颠覆者这企业宣传语好霸气啊跟小米为发烧而生有得一拼了众筹开始一定买几个顺便送一下好朋友          -2
# 38062                                         怎么知道自己是幸运者          -2
# 38122                       如果抽到幸运者会是我就太感谢了后期我会一直关注和推荐的的          -3
# 38172                                    使我们低收入者的福音呀功德一件          -3
# 38397         能不能加个轴的档位豪华套装不太适合已经买了鼠标键盘的消费者前段时间京东外设优惠刚买过          -1
# 38416                                             憨笑王者归来          -2
# 38479  我还是继续观望主要是你们也没做个测试像那种每天最高亮度半个小时可以看周这样读者心里就有数了待...          -1
# 38908      跑步的比打篮球的更关注运动数据跑者不会选择穿着篮球鞋跑步的设计团队对运动人群缺乏必要的了解          -1
# 39289  这个价格应该加入安卓系统通过家用可在家中任意位置投影内容这款产品构思还不错但局限性太多让购买...          -3
# 39664                                             有爱好者群吗          -3
# 39824  谢谢您的建议确实在宣传的时候以高配版本为蓝本来做的文案忽略了明确告知消费者低配版本的电池型号...          -1
# 39941  支持下用过穷游家出的一款双肩背包说实话非常良心这年头真把消费者当回事儿认认真真做产品的商家也...          -3
# 40176                       第一个咨询者请问如何使用这款产品能够获得高品质的声音效果          -1
# 40607                              航空母舰前来报到拥有者笑看楼下的腊鸡们再见          -4
# 40665                              拥有者表示什么腊鸡机械键盘我航母键盘秒杀之          -4
              抽到幸运幸运者会太感谢后期我会一直关注推荐
# 42392                                 收入低收入收入者低收入者福音功德一件
# 42394                                        价格算对得起消费消费者
# 42561                                            知道幸运幸运者
# 42624                              抽到幸运幸运者会太感谢后期我会一直关注推荐
# 42678                                 收入低收入收入者低收入者福音功德一件
# 42683                                        价格算对得起消费消费者
# 42849                                            知道幸运幸运者
# 42911                              抽到幸运幸运者会太感谢后期我会一直关注推荐
# 42962                                 收入低收入收入者低收入者福音功德一件
# 42967                                        价格算对得起消费消费者
# 43140                                            知道幸运幸运者
# 43200                              抽到幸运幸运者会太感谢后期我会一直关注推荐
# 43245                                 收入低收入收入者低收入者福音功德一件
# 43250                                        价格算对得起消费消费者
# 43658                       功能多功能知道告诉消费消费者一下重力感应记录鼠标移动轨迹
# 43669                      我司有个天生歌姬每次跑调总是串词灵魂听者听之后直接灵魂出窍
# 43750  对手您好砖投金石魔法影院没正式上市亲应该没可能使用这款新产品诽谤恶性竞争恶性竞争会坚决抵制光...
# 44298  古版年画市面面上市面上新刻版年画机制版年画有着本质区别市场销售年画仿照古版刻制画面呆滞印制粗...
# 44345  收藏证书山东东大大学山东大学历史文化学院中国出版工作作者协会工作者中国出版工作者协会年画艺术...
# 44367  古版年画市面面上市面上新刻版年画机制版年画有着本质区别市场销售木版年画有的是现代代人现代人仿...
# 44478  感谢感谢您提出问题优派系列专业色彩显示显示器相比普通显示显示器色彩表现表现力性能维持色彩稳定...
# 44888                                           长者暴力膜蛤节奏
# 46079                              抽到幸运幸运者会太感谢后期我会一直关注推荐
# 46106      感谢感谢您关注支持魔碟拥有拥有者解绑转给其他人使用想产品一起深入交流请加群
# 46284  米维斯传说中烧火火棍烧火棍绝不不能绝不能发烧而生拥有一把清亮帅气单板吉他一个初学学者初学者梦...
# 46328             请问一下现在马哈雅马哈吉他优势地方地方不同种比较适合初学学者初学者纠结犹豫中
# 46335                    棒吉他 作吉他爱好好者爱好者 贫穷学生党一枚 真希望 一把吉他
# 46340                     吉他爱好好者爱好者真的一个福音一个吉他初学学者初学者重要奸笑
# 46396  米维斯 指尖神话启蒙师神话意思价格之前根本见不到玫瑰木背测板面单 启蒙师意思维斯拉维斯出品一...
# 46412  吉他发烧烧友发烧友月中知道款吉他前天维斯拉维斯微博吉他中国公众号看到款吉他发布文章初学学者初...
# 46427  款入门吉他简直亮瞎合金钛合金双眼入门入门级价格高级面单材料音色更变态竟然减少初学学者初学者练...

# %%
new_col = []
for text in test.Text.head().iteritems():
    seg_list = jieba.cut_for_search(text[1])
    final_str = ""
    for seg in seg_list:
        if seg not in stop_chinese:
            final_str = final_str+seg
    new_col.append(final_str)
#     list(text)[1] = final_str
#     tuple(text)
#     print(text)
#     print(list(text)[1])

# %%
new_col
# Out:
# ['帮设计表白图案想买一件那种设计图案图案画衣服丙烯丙烯画那种初步草图不知设计设计师帮完善 再画衣服',
#  '感觉设计设计师拼颜值看好支持颜值高支持有点想支持',
#  '开卖疑问',
#  '几点',
#  '具体时间']

# %%
testest = []

# %%
str_in = '多次下单哈哈'
seg_list = jieba.cut_for_search(str_in)
final_str = ""
for seg in seg_list:
    if seg not in stop_chinese:
        final_str = final_str+seg
print(final_str)
# Out:
# 多次下单
